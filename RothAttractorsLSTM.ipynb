# %%
import numpy as np
import pandas as pd
import networkx as nx
import plotly.graph_objects as go
import holoviews as hv
import tensorflow as tf
import json

from holoviews import opts
from bokeh.plotting import show
from plotly.offline import plot
from Detector import DriverDetector
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import History
from tensorflow.keras.models import load_model
# Out:
# 2025-03-31 00:44:12.640297: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
####################################################
# prep data by removing rows with unacceptable quality or null values
# as well as removing the quality columns
# save the data to a checkpoint file for testing and reusability
####################################################

data = pd.read_csv('Data.csv')
sensors=[]

for column in data.columns:
    if column.endswith("]"):
        sensors.append(column)

def Qual_Trim(df):
        
    for sensor in sensors:
        df = df.drop(df[df[sensor + ' Quality'] != 'Acceptable'].index)
        df = df.drop(df[df[sensor].isnull()].index)
        df = df.drop([sensor + ' Quality', sensor + ' Quality Last Modified'], axis=1)
    return(df)

data = Qual_Trim(data)

data.to_csv('checkpoint', sep=',', encoding='utf-8',index=False,float_format='%.2f')
sensors= sensors[2:]

# %%
####################################################
# take a subset of the data to run the detector, this still takes a long time and is not necessary to run the detector on the entire dataset, but be sure to take enough data to get a good result
# save results to a file for further analysis and later use, this means the detector does not have to be run every time
# 
####################################################
for sensor in sensors:
        
                try:
                        data = data.head(6000)
                        data = data.tail(500)
                        print(sensor)
                        mytargetSeries = data[sensor].to_numpy()
                        mypossibleDrivers = data.drop(["Datetime", sensor], axis='columns').astype(float)
                        DD = DriverDetector(mytargetSeries, mypossibleDrivers)
                        results=DD.analyse()
                        display(results)
        # Identify columns to drop based on values in the specified row
                        columns_to_drop = results.columns[results.iloc[0] == 'N']
        # Drop identified columns
                        net = results.drop(columns=columns_to_drop)
                        fileName = sensor.replace('/', '?')
                        results.to_csv('Data/' +fileName, sep=',', encoding='utf-8',index=False,float_format='%.2f')
        #DD.saveResults(path)
                except:
                        print(sensor + 'fail')

# %%
####################################################
# create a list of links between sensors based on the results of the detector
# save the list to a file for later use
####################################################
links = []

for sensor in sensors:
    try:
        
        fileName = sensor = sensor.replace('/', '?')
        data = pd.read_csv('Data/' + fileName)
        columns_with_Y = data.columns[data.loc[0] == 'Y']
        columns_with_Y = data.columns[pd.to_numeric(data.loc[2], errors='coerce').fillna(-float('inf')) > 0.8]

        row_2_values = data.loc[2, columns_with_Y]
        row_2_values.index = columns_with_Y
        for index in columns_with_Y:
            links.append([fileName,(index.replace('/', '?')),row_2_values[index]])
    except Exception as e:
        print(e)

links

with open('links.json', 'w') as f:
    json.dump(links, f)
# Out:
# [Errno 2] No such file or directory: 'Data/Relative Humidity (% RH) [Site]'
# [Errno 2] No such file or directory: 'Data/Solar Radiation (W?m2) [Site]'

# %%
links
# Out:
# [['Flow (l?s) [Catchment 3]', 'Flow (l?s) [Catchment 6]', '0.89'],
#  ['Flow (l?s) [Catchment 3]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 8]',
#   '0.9'],
#  ['Flow (l?s) [Catchment 6]', 'Flow (l?s) [Catchment 3]', '0.87'],
#  ['Flow (l?s) [Catchment 6]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 13]',
#   '0.89'],
#  ['Flow (l?s) [Catchment 6]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 14]',
#   '0.82'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 1]',
#   'Flow (l?s) [Catchment 3]',
#   '0.93'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 1]',
#   'Flow (l?s) [Catchment 6]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 1]',
#   'Air Temperature (oC) [Site]',
#   '0.85'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 1]',
#   'Solar Radiation (W?m2) [Site]',
#   '0.86'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 1]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 2]',
#   '0.99'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 1]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 3]',
#   '0.99'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 1]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 4 After  2013?08?13]',
#   '0.99'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 1]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 5]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 1]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 6]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 1]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 7]',
#   '0.99'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 1]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 8]',
#   '0.99'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 1]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 9]',
#   '0.99'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 1]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 10]',
#   '0.99'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 1]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 11]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 1]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 12]',
#   '0.99'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 1]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 13]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 1]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 14]',
#   '0.97'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 1]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 15]',
#   '0.97'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 1]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 8]',
#   '0.96'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 1]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 9]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 1]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 10]',
#   '0.87'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 1]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 11]',
#   '0.81'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 1]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 13]',
#   '0.84'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 2]',
#   'Flow (l?s) [Catchment 3]',
#   '0.87'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 2]',
#   'Flow (l?s) [Catchment 6]',
#   '0.87'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 2]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 1]',
#   '0.99'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 2]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 3]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 2]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 4 After  2013?08?13]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 2]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 5]',
#   '0.99'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 2]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 6]',
#   '0.99'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 2]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 7]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 2]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 8]',
#   '0.97'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 2]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 9]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 2]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 10]',
#   '0.99'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 2]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 11]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 2]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 12]',
#   '0.99'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 2]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 13]',
#   '0.97'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 2]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 14]',
#   '0.95'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 2]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 15]',
#   '0.95'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 2]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 8]',
#   '0.93'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 2]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 9]',
#   '0.99'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 2]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 11]',
#   '0.82'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 3]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 1]',
#   '0.87'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 3]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 2]',
#   '0.86'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 3]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 4 After  2013?08?13]',
#   '0.91'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 3]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 5]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 3]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 6]',
#   '0.93'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 3]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 7]',
#   '0.94'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 3]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 8]',
#   '0.84'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 3]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 9]',
#   '0.93'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 3]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 10]',
#   '0.89'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 3]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 11]',
#   '0.86'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 3]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 12]',
#   '0.81'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 3]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 13]',
#   '0.96'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 3]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 14]',
#   '0.95'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 3]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 15]',
#   '0.89'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 4 After  2013?08?13]',
#   'Flow (l?s) [Catchment 3]',
#   '0.97'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 4 After  2013?08?13]',
#   'Flow (l?s) [Catchment 6]',
#   '0.95'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 4 After  2013?08?13]',
#   'Air Temperature (oC) [Site]',
#   '0.87'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 4 After  2013?08?13]',
#   'Solar Radiation (W?m2) [Site]',
#   '0.9'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 4 After  2013?08?13]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 1]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 4 After  2013?08?13]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 2]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 4 After  2013?08?13]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 3]',
#   '0.96'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 4 After  2013?08?13]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 5]',
#   '0.97'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 4 After  2013?08?13]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 6]',
#   '0.99'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 4 After  2013?08?13]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 7]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 4 After  2013?08?13]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 8]',
#   '0.96'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 4 After  2013?08?13]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 9]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 4 After  2013?08?13]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 10]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 4 After  2013?08?13]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 11]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 4 After  2013?08?13]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 12]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 4 After  2013?08?13]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 13]',
#   '0.93'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 4 After  2013?08?13]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 14]',
#   '0.93'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 4 After  2013?08?13]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 15]',
#   '0.89'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 4 After  2013?08?13]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 8]',
#   '0.94'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 4 After  2013?08?13]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 9]',
#   '0.92'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 4 After  2013?08?13]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 13]',
#   '0.91'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 4 After  2013?08?13]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 14]',
#   '0.85'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 5]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 1]',
#   '0.91'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 5]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 2]',
#   '0.88'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 5]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 3]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 5]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 4 After  2013?08?13]',
#   '0.93'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 5]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 6]',
#   '0.96'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 5]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 7]',
#   '0.95'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 5]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 8]',
#   '0.84'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 5]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 9]',
#   '0.95'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 5]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 10]',
#   '0.92'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 5]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 11]',
#   '0.88'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 5]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 12]',
#   '0.85'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 5]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 13]',
#   '0.94'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 5]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 14]',
#   '0.92'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 5]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 11]',
#   '0.82'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 6]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 1]',
#   '0.96'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 6]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 2]',
#   '0.95'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 6]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 3]',
#   '0.96'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 6]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 4 After  2013?08?13]',
#   '0.97'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 6]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 5]',
#   '0.96'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 6]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 7]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 6]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 8]',
#   '0.94'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 6]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 9]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 6]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 10]',
#   '0.97'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 6]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 11]',
#   '0.96'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 6]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 12]',
#   '0.93'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 6]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 13]',
#   '0.89'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 6]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 14]',
#   '0.93'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 6]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 9]',
#   '0.89'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 7]',
#   'Flow (l?s) [Catchment 6]',
#   '0.88'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 7]',
#   'Air Temperature (oC) [Site]',
#   '0.88'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 7]',
#   'Solar Radiation (W?m2) [Site]',
#   '0.88'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 7]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 1]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 7]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 2]',
#   '0.97'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 7]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 3]',
#   '0.96'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 7]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 4 After  2013?08?13]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 7]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 5]',
#   '0.96'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 7]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 6]',
#   '0.99'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 7]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 8]',
#   '0.96'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 7]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 9]',
#   '1.0'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 7]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 10]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 7]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 11]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 7]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 12]',
#   '0.96'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 7]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 13]',
#   '0.9'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 7]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 14]',
#   '0.95'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 7]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 15]',
#   '0.83'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 7]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 1]',
#   '0.85'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 7]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 9]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 7]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 13]',
#   '0.9'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 7]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 14]',
#   '0.88'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 8]',
#   'Flow (l?s) [Catchment 3]',
#   '0.94'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 8]',
#   'Flow (l?s) [Catchment 6]',
#   '0.94'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 8]',
#   'Solar Radiation (W?m2) [Site]',
#   '0.81'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 8]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 1]',
#   '0.99'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 8]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 2]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 8]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 3]',
#   '0.97'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 8]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 4 After  2013?08?13]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 8]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 5]',
#   '0.97'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 8]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 6]',
#   '0.96'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 8]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 7]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 8]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 9]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 8]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 10]',
#   '0.99'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 8]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 11]',
#   '0.99'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 8]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 12]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 8]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 13]',
#   '0.96'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 8]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 14]',
#   '0.95'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 8]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 15]',
#   '0.94'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 8]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 1]',
#   '0.86'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 8]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 3]',
#   '0.82'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 8]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 5]',
#   '0.89'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 8]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 8]',
#   '0.94'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 8]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 9]',
#   '0.92'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 8]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 10]',
#   '0.88'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 9]',
#   'Flow (l?s) [Catchment 6]',
#   '0.88'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 9]',
#   'Air Temperature (oC) [Site]',
#   '0.85'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 9]',
#   'Solar Radiation (W?m2) [Site]',
#   '0.86'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 9]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 1]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 9]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 2]',
#   '0.97'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 9]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 3]',
#   '0.96'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 9]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 4 After  2013?08?13]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 9]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 5]',
#   '0.96'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 9]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 6]',
#   '0.99'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 9]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 7]',
#   '0.99'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 9]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 8]',
#   '0.96'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 9]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 10]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 9]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 11]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 9]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 12]',
#   '0.96'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 9]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 13]',
#   '0.9'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 9]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 14]',
#   '0.95'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 9]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 15]',
#   '0.84'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 9]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 1]',
#   '0.85'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 9]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 9]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 9]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 13]',
#   '0.91'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 9]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 14]',
#   '0.89'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 10]',
#   'Flow (l?s) [Catchment 3]',
#   '0.81'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 10]',
#   'Flow (l?s) [Catchment 6]',
#   '0.9'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 10]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 1]',
#   '0.99'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 10]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 2]',
#   '0.99'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 10]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 3]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 10]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 4 After  2013?08?13]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 10]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 5]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 10]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 6]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 10]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 7]',
#   '0.99'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 10]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 8]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 10]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 9]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 10]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 11]',
#   '0.99'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 10]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 12]',
#   '0.99'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 10]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 13]',
#   '0.97'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 10]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 14]',
#   '0.96'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 10]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 15]',
#   '0.95'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 10]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 8]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 10]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 9]',
#   '0.99'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 10]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 10]',
#   '0.87'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 10]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 11]',
#   '0.81'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 11]',
#   'Flow (l?s) [Catchment 3]',
#   '0.9'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 11]',
#   'Flow (l?s) [Catchment 6]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 11]',
#   'Flow (l?s) [Catchment 13]',
#   '0.81'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 11]',
#   'Air Temperature (oC) [Site]',
#   '0.93'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 11]',
#   'Solar Radiation (W?m2) [Site]',
#   '0.94'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 11]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 1]',
#   '0.99'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 11]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 2]',
#   '0.99'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 11]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 3]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 11]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 4 After  2013?08?13]',
#   '0.99'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 11]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 5]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 11]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 6]',
#   '0.97'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 11]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 7]',
#   '0.99'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 11]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 8]',
#   '0.99'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 11]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 9]',
#   '0.99'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 11]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 10]',
#   '0.99'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 11]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 12]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 11]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 13]',
#   '0.96'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 11]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 14]',
#   '0.97'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 11]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 15]',
#   '0.95'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 11]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 5]',
#   '0.82'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 11]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 8]',
#   '0.92'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 11]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 9]',
#   '0.96'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 11]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 10]',
#   '0.87'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 11]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 11]',
#   '0.81'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 11]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 13]',
#   '0.93'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 11]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 14]',
#   '0.96'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 12]',
#   'Flow (l?s) [Catchment 3]',
#   '0.96'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 12]',
#   'Flow (l?s) [Catchment 6]',
#   '0.9'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 12]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 1]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 12]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 2]',
#   '0.99'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 12]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 3]',
#   '0.96'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 12]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 4 After  2013?08?13]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 12]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 5]',
#   '0.97'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 12]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 6]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 12]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 7]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 12]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 8]',
#   '0.97'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 12]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 9]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 12]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 10]',
#   '0.99'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 12]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 11]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 12]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 13]',
#   '0.95'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 12]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 14]',
#   '0.93'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 12]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 15]',
#   '0.92'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 12]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 8]',
#   '0.96'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 12]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 9]',
#   '0.98'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 13]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 3]',
#   '0.95'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 13]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 4 After  2013?08?13]',
#   '0.83'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 13]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 5]',
#   '0.95'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 13]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 6]',
#   '0.87'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 13]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 7]',
#   '0.84'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 13]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 9]',
#   '0.83'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 13]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 10]',
#   '0.83'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 13]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 14]',
#   '0.86'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 13]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 15]',
#   '0.9'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 14]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 1]',
#   '0.84'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 14]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 2]',
#   '0.84'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 14]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 3]',
#   '0.97'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 14]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 4 After  2013?08?13]',
#   '0.85'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 14]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 5]',
#   '0.93'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 14]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 6]',
#   '0.89'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 14]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 7]',
#   '0.89'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 14]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 9]',
#   '0.88'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 14]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 10]',
#   '0.84'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 14]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 11]',
#   '0.82'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 14]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 12]',
#   '0.81'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 14]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 13]',
#   '0.9'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 14]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 15]',
#   '0.9'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 15]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 3]',
#   '0.88'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 15]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 5]',
#   '0.83'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 15]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 13]',
#   '0.9'],
#  ['Soil Temperature @ 15cm Depth (oC) [Catchment 15]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 14]',
#   '0.89'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 3]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 5]',
#   '0.81'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 4 After  2013?08?13]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 13]',
#   '0.82'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 8]',
#   'Flow (l?s) [Catchment 3]',
#   '0.93'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 8]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 1]',
#   '0.9'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 8]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 2]',
#   '0.93'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 8]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 3]',
#   '0.84'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 8]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 4 After  2013?08?13]',
#   '0.89'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 8]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 5]',
#   '0.87'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 8]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 6]',
#   '0.9'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 8]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 7]',
#   '0.86'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 8]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 8]',
#   '0.91'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 8]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 9]',
#   '0.87'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 8]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 10]',
#   '0.92'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 8]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 11]',
#   '0.92'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 8]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 12]',
#   '0.94'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 8]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 13]',
#   '0.86'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 8]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 15]',
#   '0.85'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 8]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 9]',
#   '0.95'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 8]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 11]',
#   '0.84'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 9]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 1]',
#   '0.85'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 9]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 2]',
#   '0.89'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 9]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 4 After  2013?08?13]',
#   '0.82'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 9]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 5]',
#   '0.83'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 9]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 6]',
#   '0.85'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 9]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 7]',
#   '0.81'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 9]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 8]',
#   '0.89'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 9]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 9]',
#   '0.82'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 9]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 10]',
#   '0.87'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 9]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 11]',
#   '0.87'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 9]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 12]',
#   '0.89'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 10]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 1]',
#   '0.9'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 10]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 2]',
#   '0.91'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 10]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 3]',
#   '0.87'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 10]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 4 After  2013?08?13]',
#   '0.9'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 10]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 5]',
#   '0.89'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 10]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 6]',
#   '0.93'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 10]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 7]',
#   '0.89'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 10]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 8]',
#   '0.89'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 10]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 9]',
#   '0.89'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 10]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 10]',
#   '0.93'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 10]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 11]',
#   '0.9'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 10]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 12]',
#   '0.89'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 10]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 9]',
#   '0.81'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 11]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 3]',
#   '0.84'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 11]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 5]',
#   '0.89'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 11]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 6]',
#   '0.84'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 11]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 7]',
#   '0.86'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 11]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 9]',
#   '0.86'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 11]',
#   'Soil Temperature @ 15cm Depth (oC) [Catchment 13]',
#   '0.82'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 13]',
#   'Flow (l?s) [Catchment 6]',
#   '0.84'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 13]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 14]',
#   '0.95'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 14]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 1]',
#   '0.81'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 14]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 9]',
#   '0.87'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 14]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 10]',
#   '0.83'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 14]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 13]',
#   '0.95'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 15]',
#   'Flow (l?s) [Catchment 6]',
#   '0.89'],
#  ['Soil Moisture @ 10cm Depth (%) [Catchment 15]',
#   'Soil Moisture @ 10cm Depth (%) [Catchment 13]',
#   '0.85']]

# %%
# import os
# import pandas as pd
# import numpy as np
# import tensorflow as tf
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import InputLayer, LSTM, Dense
# from tensorflow.keras.callbacks import ModelCheckpoint
# from tensorflow.keras.losses import MeanSquaredError
# from tensorflow.keras.optimizers import Adam
# from tensorflow.keras.metrics import RootMeanSquaredError
# import difflib

# def normalize_string(s):
#     return ''.join(e for e in s if e.isalnum())

# def get_matching_columns(df, sensor):
#     matching_columns = []
#     for col in df.columns:
#         processed_col_name = col.replace(' ', '')
#         if sensor in processed_col_name:
#             matching_columns.append(col)
#     return matching_columns

# window_size = 5
# def df_to_X_y(df, window_size, Sensor):
#     df_as_np = df.to_numpy()
#     x = []
#     y = []
#     #myColumn = None

#     # Process DataFrame column names to match the Sensor variable
#     matching_columns = get_matching_columns(df, Sensor)
        
#     # Print matching columns for debugging
#     print(f"Matching columns for sensor '{Sensor}': {matching_columns}")
        
#     if matching_columns:
#         myColumn = df.columns.get_loc(matching_columns[-1])
#     else:
#         print('No matching column found for Sensor:', Sensor)
#         return None, None

#     for i in range(len(df_as_np)-window_size):
#         row = [a for a in df_as_np[i:i+window_size]]
#         x.append(row)
#         label = df_as_np[i+window_size][myColumn]
#         y.append(label)

#     return np.array(x), np.array(y)

# directory = os.fsencode('Data')

# for file, link in zip(os.listdir(directory), links):
#     sensor = os.fsdecode(file)
#     print(f"Processing sensor: {sensor}")

#     def find_unique_partners(links, sensor):
#         partners = {partner for pair in links for partner in pair if sensor in pair and partner != sensor}
#         return [partner.replace(' ', '') for partner in partners]


#     unique_partners = find_unique_partners(links, sensor)
#     unique_partners.insert(0, sensor)

#     # filter out elements that start with '0' as they are the correlation not the sensor
#     unique_partners = [item for item in unique_partners if not item.startswith('0')]
#     print(f"unique columns: {unique_partners}")
#     df = pd.read_csv('Data.csv')
#     df = df.fillna(-120)  # Replace null values with -120
#     for column in df.columns:
#         if column.endswith("]"):
#             sensors.append(column)
    
#     df = df.drop(df[df[column].isnull()].index)

#     # Print DataFrame columns for debugging
#     print(f"DataFrame columns: {df.columns.tolist()}")

#     # Split the sensor string into words
#     sensor_words = sensor.split()

#     # Process the columns
#     #processed_columns = [col.split('(')[0] + col.split(' ')[-1].split(']')[0] for col in df.columns]
#     #processed_columns = [col.replace(' ', '') for col in processed_columns]
#     processed_columns = [col for col in df.columns]
#     # Print processed columns for debugging
#     print(f"Processed columns: {processed_columns}")



#     def contains_all_letters_in_order(column, sensor):
#         it = iter(column)
#         return all(char in it for char in sensor)

#     filtered_columns = [col for col in df.columns if contains_all_letters_in_order(col, sensor)]

#     for column in df.columns:
#         if 'quality' not in column.lower() and sensor in column:
#             print(f"Column: {column}, Sensor: {sensor}")



# # Print filtered columns for debugging
#     filtered_columns = [col for col in filtered_columns if 'quality' not in col.lower()]
#     print(f"Filtered columns: {filtered_columns}")
#     # Filter the DataFrame to keep only the matched columns

#     df = df[filtered_columns]

#     # Keep only numeric columns
#     df = df.select_dtypes(include=[np.number])

#     # Call function and print shape to check
#     x, y = df_to_X_y(df, window_size, sensor)
#     if x is None or y is None:
#         print(f"Skipping sensor {sensor} due to missing data.")
#         continue

#     inputsize = x.shape[1:]
#     outputsize = y.shape[1:]

#     # Replace all non-numeric values with -120
#     x = np.where(np.isfinite(x), x, -120)
#     y = np.where(np.isfinite(y), y, -120)

#     # Ensure x and y contain only numeric data types
#     x = np.asarray(x).astype('float32')
#     y = np.asarray(y).astype('float32')

#     # Check for any non-numeric values in x and y
#     if not np.issubdtype(x.dtype, np.number):
#         non_numeric_x = x[~np.isfinite(x)]
#         print("Non-numeric values in x:", non_numeric_x)
#         raise ValueError("x contains non-numeric values")
#     if not np.issubdtype(y.dtype, np.number):
#         non_numeric_y = y[~np.isfinite(y)]
#         print("Non-numeric values in y:", non_numeric_y)
#         raise ValueError("y contains non-numeric values")
    
#     # Set some values to split the data 
#     trainSplit = round(x.shape[0]*0.75)
#     valSplit = round(x.shape[0]*0.9)
#     x_train, y_train = x[:trainSplit], y[:trainSplit]
#     X_val, y_val = x[trainSplit:valSplit], y[trainSplit:valSplit]
#     X_test, y_test = x[valSplit:], y[valSplit:]

#     # Convert numpy arrays to tensors
#     x_train = tf.convert_to_tensor(x_train, dtype=tf.float32)
#     y_train = tf.convert_to_tensor(y_train, dtype=tf.float32)
#     X_val = tf.convert_to_tensor(X_val, dtype=tf.float32)
#     y_val = tf.convert_to_tensor(y_val, dtype=tf.float32)

#     # Set arguments for training model
#     model1 = Sequential()
#     model1.add(InputLayer((inputsize)))
#     model1.add(LSTM(128))
#     model1.add(Dense(30, activation='relu'))
#     model1.add(Dense(8, activation='relu'))
#     model1.add(Dense(1, activation='linear'))
#     model1.summary()

#     # Create checkpoints in case current model isn't as accurate as previous epoch
#     cp = ModelCheckpoint('Models/' + sensor + '.keras', save_best_only=True)
#     model1.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.001), metrics=[RootMeanSquaredError()])

#     # Train the model
#     model1.fit(x_train, y_train, validation_data=(X_val, y_val), epochs=20, callbacks=[cp])

#     farmData = pd.read_csv('MyData.csv').fillna(-120)  # Replace null values with -120
#     predictdf = farmData[filtered_columns]
#     for col in predictdf.columns:
#         if sensor in col.replace(' ', ''):
#             I = predictdf.columns.get_loc(col)

#     for col in farmData.columns:
#         if sensor in col.replace(' ', ''):
#             I2 = farmData.columns.get_loc(col)
         
#     for k in range(len(farmData) - window_size):
#         processed_col = col.replace(' ', '')
#         if farmData.iloc[k+window_size, I2+1] != 'Acceptable':
#             X, y = df_to_X_y(predictdf, window_size, sensor) 
#             predX = model1.predict(X[k:k+1], verbose=0)
#             nbr = predX[0][0]

#             farmData.iat[k+window_size, I2+1] = 'Model Data'
#             farmData.iat[k+window_size, I2] = nbr
#             predictdf.iat[k+window_size, I] = nbr    

#     # Save the unedited input CSV
#     df.to_csv('UneditedInput.csv', sep=',', encoding='utf-8', index=False, float_format='%.2f')

#     # Save the CSV with model-generated values replacing non-'Acceptable' values
#     farmData.to_csv('ModelGeneratedValues.csv', sep=',', encoding='utf-8', index=False, float_format='%.2f')

#     # Create and save the CSV comparing all values to model-generated values
#     comparison_df = farmData.copy()
#     for k in range(len(farmData) - window_size):
#         if abs(farmData.iat[k+window_size, I2] - predictdf.iat[k+window_size, I]) / farmData.iat[k+window_size, I2] > 0.24:
#             comparison_df.iat[k+window_size, I2+1] = 'uncertain'
#     comparison_df.to_csv('ComparisonToModel.csv', sep=',', encoding='utf-8', index=False, float_format='%.2f')

#     # Create and save the CSV with 'Sploosh' values replaced by model-generated values
#     sploosh_replaced_df = comparison_df.copy()
#     for k in range(len(farmData) - window_size):
#         if comparison_df.iat[k+window_size, I2+1] == 'uncertain':
#             sploosh_replaced_df.iat[k+window_size, I2] = predictdf.iat[k+window_size, I]
#     sploosh_replaced_df.to_csv('uncertainReplaced.csv', sep=',', encoding='utf-8', index=False, float_format='%.2f')

#     print(sensor + ' Done')

# %%
import os 
import pandas as pd
import numpy as np  
import tensorflow as tf  
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import InputLayer, LSTM, Dense 
from tensorflow.keras.callbacks import ModelCheckpoint 
from tensorflow.keras.losses import MeanSquaredError 
from tensorflow.keras.optimizers import Adam  
from tensorflow.keras.metrics import RootMeanSquaredError  
import difflib 

# Function to normalize a string by removing non-alphanumeric characters
def normalize_string(s):
    return ''.join(e for e in s if e.isalnum())

# Function to get columns from DataFrame that match a given sensor
def get_matching_columns(df, sensor):
    matching_columns = []
    for col in df.columns:
        processed_col_name = col
        if sensor.lower() in processed_col_name.lower():
            matching_columns.append(col)
    return matching_columns

window_size = 5  # Define the window size for the data

# Function to convert DataFrame to input (X) and output (y) arrays for the model
def df_to_X_y(df, window_size, Sensor):
    df_as_np = df.to_numpy()  # Convert DataFrame to numpy array
    x = []  # Initialize list for input data
    y = []  # Initialize list for output data

    # Get columns that match the sensor
    matching_columns = get_matching_columns(df, Sensor)
        
    if matching_columns:
        myColumn = df.columns.get_loc(matching_columns[-1])  # Get the index of the last matching column
    else:
        print('No matching column found for Sensor:', Sensor)
        return None, None

    for i in range(len(df_as_np)-window_size):
        row = [a for a in df_as_np[i:i+window_size]]  # Get a window of data
        x.append(row)
        label = df_as_np[i+window_size][myColumn]  # Get the label for the window
        y.append(label)

    return np.array(x), np.array(y)

directory = os.fsencode('Data')  # Encode the directory name
df = pd.read_csv('Input.csv')  # Read the CSV file into a DataFrame
df.to_csv('UneditedInput.csv', sep=',', encoding='utf-8', index=False, float_format='%.2f')  # Save the unedited input CSV
df.to_csv('ComparisonToModel.csv', sep=',', encoding='utf-8', index=False, float_format='%.2f')  # Save the comparison CSV
df.to_csv('uncertainReplaced.csv', sep=',', encoding='utf-8', index=False, float_format='%.2f')
df.to_csv('ModelGeneratedValues.csv', sep=',', encoding='utf-8', index=False, float_format='%.2f')  # Save the CSV with model-generated values

# Loop through files in the directory
for file, link in zip(os.listdir(directory), links):
    sensor = os.fsdecode(file)  # Decode the file name

    # Function to find unique partners for a sensor
    def find_unique_partners(links, sensor):
        partners = {partner for pair in links for partner in pair if sensor in pair and partner != sensor}
        return [partner.replace('/', '?') for partner in partners]

    unique_partners = find_unique_partners(links, sensor)  # Get unique partners for the sensor
    unique_partners.insert(0, sensor)

    # Filter out elements that start with '0' as they are the correlation not the sensor
    unique_partners = [item for item in unique_partners if not item.startswith('0')]

    df = pd.read_csv('Input.csv')  # Read the CSV file into a DataFrame
    df = df.fillna(method='ffill')  # Replace null values with the value from the previous row

    for column in df.columns:
        if column.endswith("]"):
            sensors.append(column)  # Append columns ending with "]" to sensors list
    
    df = df.drop(df[df[column].isnull()].index)  # Drop rows with null values in the specified column

    processed_columns = [col for col in df.columns]
    processed_columns = [col for col in processed_columns if 'Quality' not in col]
    for col in processed_columns:
        if 'Quality' in col:
            processed_columns.remove(col)
        if 'Datetime' in col:
            processed_columns.remove(col)
    
    df = df[processed_columns]  # Filter the DataFrame to keep only the matched columns
    df = df.select_dtypes(include=[np.number])  # Keep only numeric columns

    # Call function and print shape to check
    x, y = df_to_X_y(df, window_size, sensor)
    if x is None or y is None:
        print(f"Skipping sensor {sensor} due to missing data.")
        continue

    inputsize = x.shape[1:]  # Get the input size
    outputsize = y.shape[1:]  # Get the output size

    x = np.where(np.isfinite(x), x, -120)  # Replace all non-numeric values with -120
    y = np.where(np.isfinite(y), y, -120)  

    x = np.asarray(x).astype('float32')  # Ensure x contains only numeric data types
    y = np.asarray(y).astype('float32')  

    if not np.issubdtype(x.dtype, np.number):
        non_numeric_x = x[~np.isfinite(x)]
        print("Non-numeric values in x:", non_numeric_x)
        raise ValueError("x contains non-numeric values")
    if not np.issubdtype(y.dtype, np.number):
        non_numeric_y = y[~np.isfinite(y)]
        print("Non-numeric values in y:", non_numeric_y)
        raise ValueError("y contains non-numeric values")
    
    trainSplit = round(x.shape[0]*0.75)  # Set the training split
    valSplit = round(x.shape[0]*0.9)  # Set the validation split
    x_train, y_train = x[:trainSplit], y[:trainSplit]
    X_val, y_val = x[trainSplit:valSplit], y[trainSplit:valSplit]
    X_test, y_test = x[valSplit:], y[valSplit:]

    x_train = tf.convert_to_tensor(x_train, dtype=tf.float32)
    y_train = tf.convert_to_tensor(y_train, dtype=tf.float32)
    X_val = tf.convert_to_tensor(X_val, dtype=tf.float32)
    y_val = tf.convert_to_tensor(y_val, dtype=tf.float32)

    model1 = Sequential()
    model1.add(InputLayer((inputsize)))
    model1.add(LSTM(128))
    model1.add(Dense(30, activation='relu'))
    model1.add(Dense(8, activation='relu'))
    model1.add(Dense(1, activation='linear'))

    cp = ModelCheckpoint('Models/' + sensor + '.keras', save_best_only=True)
    model1.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.001), metrics=[RootMeanSquaredError()])

    model1.fit(x_train, y_train, validation_data=(X_val, y_val), epochs=50, callbacks=[cp], verbose=0)

    farmData = pd.read_csv('Input.csv').fillna(method='ffill')  # Replace null values with the value from the previous row
    predictdf = farmData[processed_columns]
    for col in predictdf.columns:
        if sensor.replace('/', '?') in col.replace('/', '?'):
            I = predictdf.columns.get_loc(col)

    for col in farmData.columns:
        if sensor.replace('/', '?') in col.replace('/', '?'):
            I2 = farmData.columns.get_loc(col)-3

    comparison_df = pd.read_csv('ComparisonToModel.csv').astype('object')
    farmData = pd.read_csv('ModelGeneratedValues.csv').astype('object')
    replaced_df = pd.read_csv('uncertainReplaced.csv').astype('object')

    for k in range(len(farmData) - window_size):
        try:
            X, y = df_to_X_y(predictdf, window_size, sensor)
            predX = model1.predict(X[k:k+1].astype('float32'), verbose=0)
            nbr = predX[0][0]
        except Exception as e:
            print(sensor + 'prediction error')
            print(e)
        
        try:
            if farmData.iloc[k+window_size, I2+2] != 'Acceptable':
                farmData.iat[k+window_size, I2+2] = 'Infilled'
                farmData.iat[k+window_size, I2+1] = nbr  
                comparison_df.iat[k+window_size, I2+2] = 'Infilled'
                comparison_df.iat[k+window_size, I2+1] = nbr  
                replaced_df.iat[k+window_size, I2+2] = 'Infilled'
                replaced_df.iat[k+window_size, I2+1] = nbr  
                predictdf.iat[k+window_size, I] = nbr  
        except Exception as e:
            print(sensor + 'data error')
            print(e)

        try:
            if abs(nbr-farmData.iat[k+window_size, I2+1])/farmData.iat[k+window_size, I2+1] > 0.15:
                comparison_df.iat[k+window_size, I2+2] = 'uncertain'
                replaced_df.iat[k+window_size, I2+2] = 'uncertain'
        except Exception as e:
            print(sensor + 'comparison error')
            print(e)

        try:
            if replaced_df.iat[k+window_size, I2+2] == 'uncertain':
                replaced_df.iat[k+window_size, I2+1] = nbr
                replaced_df.iat[k+window_size, I2+2] = 'Replaced'
        except Exception as e:
            print(sensor + 'replacement error')
            print(e)
    print(model1.summary())
    df.to_csv('UneditedInput.csv', sep=',', encoding='utf-8', index=False, float_format='%.2f')
    farmData.to_csv('ModelGeneratedValues.csv', sep=',', encoding='utf-8', index=False, float_format='%.2f')
    comparison_df.to_csv('ComparisonToModel.csv', sep=',', encoding='utf-8', index=False, float_format='%.2f')
    replaced_df.to_csv('uncertainReplaced.csv', sep=',', encoding='utf-8', index=False, float_format='%.2f')

    print(sensor + ' Done')

# %%
import os 
import pandas as pd
import numpy as np  
import tensorflow as tf  
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import InputLayer, LSTM, Dense, Dropout, BatchNormalization, Bidirectional
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.losses import Huber
from tensorflow.keras.optimizers import Adam, RMSprop, Nadam
from tensorflow.keras.metrics import RootMeanSquaredError  
import difflib 

# Function to normalize a string by removing non-alphanumeric characters
def normalize_string(s):
    return ''.join(e for e in s if e.isalnum())

# Function to get columns from DataFrame that match a given sensor
def get_matching_columns(df, sensor):
    matching_columns = []
    for col in df.columns:
        processed_col_name = col
        if sensor.lower() in processed_col_name.lower():
            matching_columns.append(col)
    return matching_columns

window_size = 5  # Define the window size for the data

# Function to convert DataFrame to input (X) and output (y) arrays for the model
# Function to convert DataFrame to input (X) and output (y) arrays for the model
def df_to_X_y(df, window_size, Sensor, output_weight=1.5):
    df_as_np = df.to_numpy()  # Convert DataFrame to numpy array
    x = []  # Initialize list for input data
    y = []  # Initialize list for output data

    # Get columns that match the sensor
    matching_columns = get_matching_columns(df, Sensor)
        
    if matching_columns:
        myColumn = df.columns.get_loc(matching_columns[-1])  # Get the index of the last matching column
    else:
        print('No matching column found for Sensor:', Sensor)
        return None, None

    for i in range(len(df_as_np) - window_size):
        row = df_as_np[i:i+window_size].copy()  # Include all columns in the input window
        x.append(row)
        label = df_as_np[i+window_size][myColumn]  # Get the label for the window
        y.append(label)

    return np.array(x), np.array(y)

directory = os.fsencode('Data')  # Encode the directory name
df = pd.read_csv('Input.csv')  # Read the CSV file into a DataFrame
df = df.ffill()  # Replace null values with the value from the previous row
df.to_csv('UneditedInput.csv', sep=',', encoding='utf-8', index=False, float_format='%.2f')  # Save the unedited input CSV
df.to_csv('ComparisonToModel.csv', sep=',', encoding='utf-8', index=False, float_format='%.2f')  # Save the comparison CSV
df.to_csv('uncertainReplaced.csv', sep=',', encoding='utf-8', index=False, float_format='%.2f')
df.to_csv('ModelGeneratedValues.csv', sep=',', encoding='utf-8', index=False, float_format='%.2f')  # Save the CSV with model-generated values

# Loop through files in the directory
for file, link in zip(os.listdir(directory), links):
    sensor = os.fsdecode(file).replace('?','/')  # Decode the file name

    # Function to find unique partners for a sensor
    def find_unique_partners(links, sensor):
        partners = {partner for pair in links for partner in pair if sensor in pair and partner != sensor}
        return [partner.replace('/', '?') for partner in partners]

    unique_partners = find_unique_partners(links, sensor)  # Get unique partners for the sensor
    unique_partners.insert(0, sensor)

    # Filter out elements that start with '0' as they are the correlation not the sensor
    unique_partners = [item for item in unique_partners if not item.startswith('0')]

    df = pd.read_csv('Input.csv')  # Read the CSV file into a DataFrame
    df = df.ffill()  # Replace null values with the value from the previous row

    for column in df.columns:
        if column.endswith("]"):
            sensors.append(column)  # Append columns ending with "]" to sensors list
    
    df = df.drop(df[df[column].isnull()].index)  # Drop rows with null values in the specified column

    processed_columns = [col for col in df.columns]
    processed_columns = [col for col in processed_columns if 'Quality' not in col]
    for col in processed_columns:
        if 'Quality' in col:
            processed_columns.remove(col)
        if 'Datetime' in col:
            processed_columns.remove(col)
    
    df = df[processed_columns]  # Filter the DataFrame to keep only the matched columns
    df = df.select_dtypes(include=[np.number])  # Keep only numeric columns

    # Call function and print shape to check
    x, y = df_to_X_y(df, window_size, sensor)
    if x is None or y is None:
        print(f"Skipping sensor {sensor} due to missing data.")
        continue

    inputsize = x.shape[1:]  # Get the input size
    outputsize = y.shape[1:]  # Get the output size

    x = np.where(np.isfinite(x), x, -120)  # Replace all non-numeric values with -120
    y = np.where(np.isfinite(y), y, -120)  

    x = np.asarray(x).astype('float32')  # Ensure x contains only numeric data types
    y = np.asarray(y).astype('float32')  

    if not np.issubdtype(x.dtype, np.number):
        non_numeric_x = x[~np.isfinite(x)]
        print("Non-numeric values in x:", non_numeric_x)
        raise ValueError("x contains non-numeric values")
    if not np.issubdtype(y.dtype, np.number):
        non_numeric_y = y[~np.isfinite(y)]
        print("Non-numeric values in y:", non_numeric_y)
        raise ValueError("y contains non-numeric values")
    
    trainSplit = round(x.shape[0]*0.75)  # Set the training split
    valSplit = round(x.shape[0]*0.9)  # Set the validation split
    x_train, y_train = x[:trainSplit], y[:trainSplit]
    X_val, y_val = x[trainSplit:valSplit], y[trainSplit:valSplit]
    X_test, y_test = x[valSplit:], y[valSplit:]

    x_train = tf.convert_to_tensor(x_train, dtype=tf.float32)
    y_train = tf.convert_to_tensor(y_train, dtype=tf.float32)
    X_val = tf.convert_to_tensor(X_val, dtype=tf.float32)
    y_val = tf.convert_to_tensor(y_val, dtype=tf.float32)

    # Updated model definition
    model1 = Sequential()

    # Input layer
    model1.add(InputLayer((inputsize)))

    # Bidirectional LSTM layers
    model1.add(Bidirectional(LSTM(256, return_sequences=True)))  # Bidirectional LSTM
    model1.add(Dropout(0.5))  # Increased dropout for better regularization
    model1.add(Bidirectional(LSTM(128)))  # Second Bidirectional LSTM
    model1.add(Dropout(0.5))

    # Batch normalization for faster convergence
    model1.add(BatchNormalization())

    # Fully connected layers
    model1.add(Dense(64, activation='relu'))  # Added another dense layer
    model1.add(Dense(16, activation='relu'))  # Added another dense layer
    model1.add(Dense(8, activation='relu'))  # Added another dense layer
    model1.add(Dense(1, activation='linear'))  # Output layer

    # Compile the model
    cp = ModelCheckpoint('Models/' + sensor + '.keras', save_best_only=True)
    lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=20, min_lr=1e-25)  # Increased patience to 10
    early_stopping = EarlyStopping(monitor='val_loss', patience=100, restore_best_weights=True)  # Increased patience to 20

    model1.compile(
        loss=Huber(),  # Huber loss for better handling of outliers
        optimizer=RMSprop(learning_rate=0.001),  # Lower learning rate
        metrics=[RootMeanSquaredError()]
    )

    model1.fit(
        x_train, y_train,
        validation_data=(X_val, y_val),
        epochs=50000,
        callbacks=[cp, lr_scheduler, early_stopping],
        verbose=1
    )

    farmData = pd.read_csv('Input.csv').ffill()  # Replace null values with the value from the previous row
    predictdf = farmData[processed_columns]
    for col in predictdf.columns:
        if sensor.replace('/', '?') in col.replace('/', '?'):
            I = predictdf.columns.get_loc(col)

    for col in farmData.columns:
        if sensor.replace('/', '?') in col.replace('/', '?'):
            I2 = farmData.columns.get_loc(col)-3

    comparison_df = pd.read_csv('ComparisonToModel.csv').astype('object')
    farmData = pd.read_csv('ModelGeneratedValues.csv').astype('object')
    replaced_df = pd.read_csv('uncertainReplaced.csv').astype('object')
    new_df = replaced_df.copy()

    for k in range(len(farmData) - window_size):
        try:
            X, y = df_to_X_y(predictdf, window_size, sensor)
            predX = model1.predict(X[k:k+1].astype('float32'), verbose=0)
            nbr = predX[0][0]
        except Exception as e:
            print(sensor + 'prediction error')
            print(e)
        
        try:
            if farmData.iloc[k+window_size, I2+2] != 'Acceptable':
                farmData.iat[k+window_size, I2+2] = 'Infilled'
                farmData.iat[k+window_size, I2+1] = nbr
                comparison_df.iat[k+window_size, I2+2] = 'Infilled'
                comparison_df.iat[k+window_size, I2+1] = nbr  
                replaced_df.iat[k+window_size, I2+2] = 'Infilled'
                replaced_df.iat[k+window_size, I2+1] = nbr  
                predictdf.iat[k+window_size, I] = nbr  
        except Exception as e:
            print(sensor + 'data error')
            print(e)

        try:
            if abs(nbr-farmData.iat[k+window_size, I2+1])/farmData.iat[k+window_size, I2+1] > 0.05:
                comparison_df.iat[k+window_size, I2+2] = 'uncertain'
                replaced_df.iat[k+window_size, I2+2] = 'uncertain'
        except Exception as e:
            print(sensor + 'comparison error')
            print(e)

        try:
            if replaced_df.iat[k+window_size, I2+2] == 'uncertain':
                replaced_df.iat[k+window_size, I2+1] = nbr
                replaced_df.iat[k+window_size, I2+2] = 'Replaced'
        except Exception as e:
            print(sensor + 'replacement error')
            print(e)

        try:
            new_df.iat[k+window_size, I2+1] = nbr
        except Exception as e:            
            print(sensor + 'new error')
            print(e)
    df.to_csv('UneditedInput.csv', sep=',', encoding='utf-8', index=False, float_format='%.2f')
    farmData.to_csv('ModelGeneratedValues.csv', sep=',', encoding='utf-8', index=False, float_format='%.2f')
    comparison_df.to_csv('ComparisonToModel.csv', sep=',', encoding='utf-8', index=False, float_format='%.2f')
    replaced_df.to_csv('uncertainReplaced.csv', sep=',', encoding='utf-8', index=False, float_format='%.2f')
    new_df.to_csv('new_df.csv', sep=',', encoding='utf-8', index=False, float_format='%.2f')

    print(sensor + ' Done')
# Out:
# Epoch 1/50000
# 235/235 [==============================] - 16s 37ms/step - loss: 0.8619 - root_mean_squared_error: 1.7502 - val_loss: 2.2007 - val_root_mean_squared_error: 2.8242 - lr: 0.0010
# Epoch 2/50000
# 235/235 [==============================] - 8s 34ms/step - loss: 0.3671 - root_mean_squared_error: 0.9176 - val_loss: 0.1061 - val_root_mean_squared_error: 0.4611 - lr: 0.0010
# Epoch 3/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.2761 - root_mean_squared_error: 0.7782 - val_loss: 1.6192 - val_root_mean_squared_error: 2.2168 - lr: 0.0010
# Epoch 4/50000
# 235/235 [==============================] - 7s 32ms/step - loss: 0.2355 - root_mean_squared_error: 0.7111 - val_loss: 0.4947 - val_root_mean_squared_error: 1.0332 - lr: 0.0010
# Epoch 5/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.2018 - root_mean_squared_error: 0.6512 - val_loss: 0.8694 - val_root_mean_squared_error: 1.4566 - lr: 0.0010
# Epoch 6/50000
# 235/235 [==============================] - 7s 31ms/step - loss: 0.1720 - root_mean_squared_error: 0.5976 - val_loss: 0.5819 - val_root_mean_squared_error: 1.1143 - lr: 0.0010
# Epoch 7/50000
# 235/235 [==============================] - 7s 31ms/step - loss: 0.1540 - root_mean_squared_error: 0.5632 - val_loss: 0.2157 - val_root_mean_squared_error: 0.6584 - lr: 0.0010
# Epoch 8/50000
# 235/235 [==============================] - 8s 33ms/step - loss: 0.1392 - root_mean_squared_error: 0.5339 - val_loss: 0.7528 - val_root_mean_squared_error: 1.2632 - lr: 0.0010
# Epoch 9/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.1317 - root_mean_squared_error: 0.5194 - val_loss: 0.3833 - val_root_mean_squared_error: 0.8888 - lr: 0.0010
# Epoch 10/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.1213 - root_mean_squared_error: 0.4964 - val_loss: 0.9524 - val_root_mean_squared_error: 1.4733 - lr: 0.0010
# Epoch 11/50000
# 235/235 [==============================] - 8s 32ms/step - loss: 0.1112 - root_mean_squared_error: 0.4743 - val_loss: 0.0442 - val_root_mean_squared_error: 0.2972 - lr: 0.0010
# Epoch 12/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.1004 - root_mean_squared_error: 0.4506 - val_loss: 0.5158 - val_root_mean_squared_error: 1.0396 - lr: 0.0010
# Epoch 13/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0966 - root_mean_squared_error: 0.4421 - val_loss: 0.2433 - val_root_mean_squared_error: 0.6976 - lr: 0.0010
# Epoch 14/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0921 - root_mean_squared_error: 0.4306 - val_loss: 0.3872 - val_root_mean_squared_error: 0.8836 - lr: 0.0010
# Epoch 15/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0895 - root_mean_squared_error: 0.4253 - val_loss: 0.0322 - val_root_mean_squared_error: 0.2537 - lr: 0.0010
# Epoch 16/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0822 - root_mean_squared_error: 0.4070 - val_loss: 0.5086 - val_root_mean_squared_error: 1.0226 - lr: 0.0010
# Epoch 17/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0744 - root_mean_squared_error: 0.3876 - val_loss: 0.2106 - val_root_mean_squared_error: 0.6494 - lr: 0.0010
# Epoch 18/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0699 - root_mean_squared_error: 0.3746 - val_loss: 0.3677 - val_root_mean_squared_error: 0.8658 - lr: 0.0010
# Epoch 19/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0685 - root_mean_squared_error: 0.3706 - val_loss: 0.9722 - val_root_mean_squared_error: 1.4830 - lr: 0.0010
# Epoch 20/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0705 - root_mean_squared_error: 0.3759 - val_loss: 0.0264 - val_root_mean_squared_error: 0.2297 - lr: 0.0010
# Epoch 21/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0689 - root_mean_squared_error: 0.3718 - val_loss: 0.0542 - val_root_mean_squared_error: 0.3293 - lr: 0.0010
# Epoch 22/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0588 - root_mean_squared_error: 0.3433 - val_loss: 0.6600 - val_root_mean_squared_error: 1.1708 - lr: 0.0010
# Epoch 23/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0615 - root_mean_squared_error: 0.3510 - val_loss: 0.0314 - val_root_mean_squared_error: 0.2505 - lr: 0.0010
# Epoch 24/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0584 - root_mean_squared_error: 0.3422 - val_loss: 1.1560 - val_root_mean_squared_error: 1.6653 - lr: 0.0010
# Epoch 25/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0547 - root_mean_squared_error: 0.3312 - val_loss: 0.6665 - val_root_mean_squared_error: 1.1854 - lr: 0.0010
# Epoch 26/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0559 - root_mean_squared_error: 0.3346 - val_loss: 0.4551 - val_root_mean_squared_error: 0.9587 - lr: 0.0010
# Epoch 27/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0559 - root_mean_squared_error: 0.3349 - val_loss: 0.4969 - val_root_mean_squared_error: 1.0043 - lr: 0.0010
# Epoch 28/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0516 - root_mean_squared_error: 0.3214 - val_loss: 0.0373 - val_root_mean_squared_error: 0.2731 - lr: 0.0010
# Epoch 29/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0513 - root_mean_squared_error: 0.3204 - val_loss: 0.0857 - val_root_mean_squared_error: 0.4142 - lr: 0.0010
# Epoch 30/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0503 - root_mean_squared_error: 0.3173 - val_loss: 0.0083 - val_root_mean_squared_error: 0.1292 - lr: 0.0010
# Epoch 31/50000
# 235/235 [==============================] - 7s 31ms/step - loss: 0.0509 - root_mean_squared_error: 0.3195 - val_loss: 0.0050 - val_root_mean_squared_error: 0.1002 - lr: 0.0010
# Epoch 32/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0501 - root_mean_squared_error: 0.3167 - val_loss: 0.0326 - val_root_mean_squared_error: 0.2555 - lr: 0.0010
# Epoch 33/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0482 - root_mean_squared_error: 0.3107 - val_loss: 0.1108 - val_root_mean_squared_error: 0.4711 - lr: 0.0010
# Epoch 34/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0472 - root_mean_squared_error: 0.3076 - val_loss: 0.2973 - val_root_mean_squared_error: 0.7711 - lr: 0.0010
# Epoch 35/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0458 - root_mean_squared_error: 0.3028 - val_loss: 0.1421 - val_root_mean_squared_error: 0.5330 - lr: 0.0010
# Epoch 36/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0446 - root_mean_squared_error: 0.2990 - val_loss: 0.6147 - val_root_mean_squared_error: 1.1302 - lr: 0.0010
# Epoch 37/50000
# 235/235 [==============================] - 7s 31ms/step - loss: 0.0524 - root_mean_squared_error: 0.3237 - val_loss: 0.1775 - val_root_mean_squared_error: 0.5960 - lr: 0.0010
# Epoch 38/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0453 - root_mean_squared_error: 0.3011 - val_loss: 0.0677 - val_root_mean_squared_error: 0.3679 - lr: 0.0010
# Epoch 39/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0479 - root_mean_squared_error: 0.3097 - val_loss: 0.4446 - val_root_mean_squared_error: 0.9499 - lr: 0.0010
# Epoch 40/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0442 - root_mean_squared_error: 0.2973 - val_loss: 0.7227 - val_root_mean_squared_error: 1.2316 - lr: 0.0010
# Epoch 41/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0453 - root_mean_squared_error: 0.3012 - val_loss: 0.4108 - val_root_mean_squared_error: 0.9127 - lr: 0.0010
# Epoch 42/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0462 - root_mean_squared_error: 0.3039 - val_loss: 0.0847 - val_root_mean_squared_error: 0.4115 - lr: 0.0010
# Epoch 43/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0414 - root_mean_squared_error: 0.2878 - val_loss: 0.0789 - val_root_mean_squared_error: 0.3972 - lr: 0.0010
# Epoch 44/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0401 - root_mean_squared_error: 0.2834 - val_loss: 0.4853 - val_root_mean_squared_error: 0.9897 - lr: 0.0010
# Epoch 45/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0414 - root_mean_squared_error: 0.2881 - val_loss: 0.1848 - val_root_mean_squared_error: 0.6080 - lr: 0.0010
# Epoch 46/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0407 - root_mean_squared_error: 0.2853 - val_loss: 0.0876 - val_root_mean_squared_error: 0.4185 - lr: 0.0010
# Epoch 47/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0383 - root_mean_squared_error: 0.2768 - val_loss: 0.0164 - val_root_mean_squared_error: 0.1811 - lr: 0.0010
# Epoch 48/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0402 - root_mean_squared_error: 0.2834 - val_loss: 0.1450 - val_root_mean_squared_error: 0.5385 - lr: 0.0010
# Epoch 49/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0429 - root_mean_squared_error: 0.2931 - val_loss: 0.1044 - val_root_mean_squared_error: 0.4569 - lr: 0.0010
# Epoch 50/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0374 - root_mean_squared_error: 0.2737 - val_loss: 0.3467 - val_root_mean_squared_error: 0.8330 - lr: 0.0010
# Epoch 51/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0387 - root_mean_squared_error: 0.2782 - val_loss: 0.1165 - val_root_mean_squared_error: 0.4827 - lr: 0.0010
# Epoch 52/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0226 - root_mean_squared_error: 0.2125 - val_loss: 0.0095 - val_root_mean_squared_error: 0.1379 - lr: 1.0000e-04
# Epoch 53/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0196 - root_mean_squared_error: 0.1978 - val_loss: 0.0261 - val_root_mean_squared_error: 0.2283 - lr: 1.0000e-04
# Epoch 54/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0202 - root_mean_squared_error: 0.2012 - val_loss: 0.0202 - val_root_mean_squared_error: 0.2012 - lr: 1.0000e-04
# Epoch 55/50000
# 235/235 [==============================] - 7s 31ms/step - loss: 0.0194 - root_mean_squared_error: 0.1969 - val_loss: 0.0064 - val_root_mean_squared_error: 0.1134 - lr: 1.0000e-04
# Epoch 56/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0189 - root_mean_squared_error: 0.1946 - val_loss: 0.0115 - val_root_mean_squared_error: 0.1517 - lr: 1.0000e-04
# Epoch 57/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0184 - root_mean_squared_error: 0.1918 - val_loss: 0.0134 - val_root_mean_squared_error: 0.1637 - lr: 1.0000e-04
# Epoch 58/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0199 - root_mean_squared_error: 0.1993 - val_loss: 0.0270 - val_root_mean_squared_error: 0.2324 - lr: 1.0000e-04
# Epoch 59/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0178 - root_mean_squared_error: 0.1887 - val_loss: 0.0097 - val_root_mean_squared_error: 0.1395 - lr: 1.0000e-04
# Epoch 60/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0198 - root_mean_squared_error: 0.1988 - val_loss: 0.0089 - val_root_mean_squared_error: 0.1336 - lr: 1.0000e-04
# Epoch 61/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0198 - root_mean_squared_error: 0.1992 - val_loss: 0.0186 - val_root_mean_squared_error: 0.1931 - lr: 1.0000e-04
# Epoch 62/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0173 - root_mean_squared_error: 0.1861 - val_loss: 0.0098 - val_root_mean_squared_error: 0.1399 - lr: 1.0000e-04
# Epoch 63/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0188 - root_mean_squared_error: 0.1940 - val_loss: 0.0209 - val_root_mean_squared_error: 0.2043 - lr: 1.0000e-04
# Epoch 64/50000
# 235/235 [==============================] - 7s 31ms/step - loss: 0.0184 - root_mean_squared_error: 0.1919 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0956 - lr: 1.0000e-04
# Epoch 65/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0172 - root_mean_squared_error: 0.1854 - val_loss: 0.0200 - val_root_mean_squared_error: 0.2000 - lr: 1.0000e-04
# Epoch 66/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0180 - root_mean_squared_error: 0.1900 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1650 - lr: 1.0000e-04
# Epoch 67/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0172 - root_mean_squared_error: 0.1856 - val_loss: 0.0096 - val_root_mean_squared_error: 0.1388 - lr: 1.0000e-04
# Epoch 68/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0168 - root_mean_squared_error: 0.1832 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0979 - lr: 1.0000e-04
# Epoch 69/50000
# 235/235 [==============================] - 7s 31ms/step - loss: 0.0175 - root_mean_squared_error: 0.1869 - val_loss: 0.0090 - val_root_mean_squared_error: 0.1339 - lr: 1.0000e-04
# Epoch 70/50000
# 235/235 [==============================] - 7s 31ms/step - loss: 0.0175 - root_mean_squared_error: 0.1869 - val_loss: 0.0084 - val_root_mean_squared_error: 0.1300 - lr: 1.0000e-04
# Epoch 71/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0172 - root_mean_squared_error: 0.1857 - val_loss: 0.0051 - val_root_mean_squared_error: 0.1006 - lr: 1.0000e-04
# Epoch 72/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0167 - root_mean_squared_error: 0.1826 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0960 - lr: 1.0000e-04
# Epoch 73/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0167 - root_mean_squared_error: 0.1825 - val_loss: 0.0213 - val_root_mean_squared_error: 0.2063 - lr: 1.0000e-04
# Epoch 74/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0156 - root_mean_squared_error: 0.1766 - val_loss: 0.0086 - val_root_mean_squared_error: 0.1313 - lr: 1.0000e-04
# Epoch 75/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0159 - root_mean_squared_error: 0.1782 - val_loss: 0.0240 - val_root_mean_squared_error: 0.2189 - lr: 1.0000e-04
# Epoch 76/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0164 - root_mean_squared_error: 0.1811 - val_loss: 0.0068 - val_root_mean_squared_error: 0.1168 - lr: 1.0000e-04
# Epoch 77/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0171 - root_mean_squared_error: 0.1854 - val_loss: 0.0208 - val_root_mean_squared_error: 0.2040 - lr: 1.0000e-04
# Epoch 78/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0155 - root_mean_squared_error: 0.1760 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1571 - lr: 1.0000e-04
# Epoch 79/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0164 - root_mean_squared_error: 0.1814 - val_loss: 0.0066 - val_root_mean_squared_error: 0.1147 - lr: 1.0000e-04
# Epoch 80/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0160 - root_mean_squared_error: 0.1791 - val_loss: 0.0051 - val_root_mean_squared_error: 0.1010 - lr: 1.0000e-04
# Epoch 81/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0161 - root_mean_squared_error: 0.1796 - val_loss: 0.0053 - val_root_mean_squared_error: 0.1031 - lr: 1.0000e-04
# Epoch 82/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0156 - root_mean_squared_error: 0.1766 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0959 - lr: 1.0000e-04
# Epoch 83/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0159 - root_mean_squared_error: 0.1786 - val_loss: 0.0057 - val_root_mean_squared_error: 0.1067 - lr: 1.0000e-04
# Epoch 84/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0153 - root_mean_squared_error: 0.1748 - val_loss: 0.0051 - val_root_mean_squared_error: 0.1014 - lr: 1.0000e-04
# Epoch 85/50000
# 235/235 [==============================] - 7s 31ms/step - loss: 0.0147 - root_mean_squared_error: 0.1712 - val_loss: 0.0074 - val_root_mean_squared_error: 0.1214 - lr: 1.0000e-05
# Epoch 86/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0145 - root_mean_squared_error: 0.1702 - val_loss: 0.0062 - val_root_mean_squared_error: 0.1118 - lr: 1.0000e-05
# Epoch 87/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0149 - root_mean_squared_error: 0.1724 - val_loss: 0.0069 - val_root_mean_squared_error: 0.1172 - lr: 1.0000e-05
# Epoch 88/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0142 - root_mean_squared_error: 0.1686 - val_loss: 0.0079 - val_root_mean_squared_error: 0.1260 - lr: 1.0000e-05
# Epoch 89/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0144 - root_mean_squared_error: 0.1695 - val_loss: 0.0066 - val_root_mean_squared_error: 0.1145 - lr: 1.0000e-05
# Epoch 90/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0146 - root_mean_squared_error: 0.1709 - val_loss: 0.0059 - val_root_mean_squared_error: 0.1087 - lr: 1.0000e-05
# Epoch 91/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0157 - root_mean_squared_error: 0.1773 - val_loss: 0.0063 - val_root_mean_squared_error: 0.1125 - lr: 1.0000e-05
# Epoch 92/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0148 - root_mean_squared_error: 0.1721 - val_loss: 0.0082 - val_root_mean_squared_error: 0.1280 - lr: 1.0000e-05
# Epoch 93/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0151 - root_mean_squared_error: 0.1736 - val_loss: 0.0067 - val_root_mean_squared_error: 0.1159 - lr: 1.0000e-05
# Epoch 94/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0150 - root_mean_squared_error: 0.1733 - val_loss: 0.0075 - val_root_mean_squared_error: 0.1229 - lr: 1.0000e-05
# Epoch 95/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0135 - root_mean_squared_error: 0.1644 - val_loss: 0.0087 - val_root_mean_squared_error: 0.1316 - lr: 1.0000e-05
# Epoch 96/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0141 - root_mean_squared_error: 0.1682 - val_loss: 0.0074 - val_root_mean_squared_error: 0.1215 - lr: 1.0000e-05
# Epoch 97/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0149 - root_mean_squared_error: 0.1724 - val_loss: 0.0052 - val_root_mean_squared_error: 0.1022 - lr: 1.0000e-05
# Epoch 98/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0147 - root_mean_squared_error: 0.1715 - val_loss: 0.0073 - val_root_mean_squared_error: 0.1206 - lr: 1.0000e-05
# Epoch 99/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0154 - root_mean_squared_error: 0.1757 - val_loss: 0.0071 - val_root_mean_squared_error: 0.1194 - lr: 1.0000e-05
# Epoch 100/50000
# 235/235 [==============================] - 7s 28ms/step - loss: 0.0148 - root_mean_squared_error: 0.1723 - val_loss: 0.0079 - val_root_mean_squared_error: 0.1260 - lr: 1.0000e-05
# Epoch 101/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0139 - root_mean_squared_error: 0.1669 - val_loss: 0.0092 - val_root_mean_squared_error: 0.1353 - lr: 1.0000e-05
# Epoch 102/50000
# 235/235 [==============================] - 368s 2s/step - loss: 0.0150 - root_mean_squared_error: 0.1732 - val_loss: 0.0077 - val_root_mean_squared_error: 0.1242 - lr: 1.0000e-05
# Epoch 103/50000
# 235/235 [==============================] - 8s 33ms/step - loss: 0.0140 - root_mean_squared_error: 0.1673 - val_loss: 0.0095 - val_root_mean_squared_error: 0.1377 - lr: 1.0000e-05
# Epoch 104/50000
# 235/235 [==============================] - 26s 112ms/step - loss: 0.0133 - root_mean_squared_error: 0.1634 - val_loss: 0.0092 - val_root_mean_squared_error: 0.1359 - lr: 1.0000e-05
# Epoch 105/50000
# 235/235 [==============================] - 1404s 6s/step - loss: 0.0153 - root_mean_squared_error: 0.1748 - val_loss: 0.0081 - val_root_mean_squared_error: 0.1269 - lr: 1.0000e-06
# Epoch 106/50000
# 235/235 [==============================] - 10s 42ms/step - loss: 0.0145 - root_mean_squared_error: 0.1700 - val_loss: 0.0072 - val_root_mean_squared_error: 0.1196 - lr: 1.0000e-06
# Epoch 107/50000
# 235/235 [==============================] - 27s 115ms/step - loss: 0.0148 - root_mean_squared_error: 0.1721 - val_loss: 0.0074 - val_root_mean_squared_error: 0.1216 - lr: 1.0000e-06
# Epoch 108/50000
# 235/235 [==============================] - 27s 114ms/step - loss: 0.0152 - root_mean_squared_error: 0.1742 - val_loss: 0.0069 - val_root_mean_squared_error: 0.1179 - lr: 1.0000e-06
# Epoch 109/50000
# 235/235 [==============================] - 26s 110ms/step - loss: 0.0146 - root_mean_squared_error: 0.1710 - val_loss: 0.0069 - val_root_mean_squared_error: 0.1175 - lr: 1.0000e-06
# Epoch 110/50000
# 235/235 [==============================] - 25s 108ms/step - loss: 0.0134 - root_mean_squared_error: 0.1639 - val_loss: 0.0065 - val_root_mean_squared_error: 0.1136 - lr: 1.0000e-06
# Epoch 111/50000
# 235/235 [==============================] - 470s 2s/step - loss: 0.0148 - root_mean_squared_error: 0.1723 - val_loss: 0.0068 - val_root_mean_squared_error: 0.1169 - lr: 1.0000e-06
# Epoch 112/50000
# 235/235 [==============================] - 14s 61ms/step - loss: 0.0142 - root_mean_squared_error: 0.1685 - val_loss: 0.0070 - val_root_mean_squared_error: 0.1183 - lr: 1.0000e-06
# Epoch 113/50000
# 235/235 [==============================] - 26s 111ms/step - loss: 0.0138 - root_mean_squared_error: 0.1662 - val_loss: 0.0073 - val_root_mean_squared_error: 0.1206 - lr: 1.0000e-06
# Epoch 114/50000
# 235/235 [==============================] - 15s 62ms/step - loss: 0.0148 - root_mean_squared_error: 0.1723 - val_loss: 0.0076 - val_root_mean_squared_error: 0.1231 - lr: 1.0000e-06
# Epoch 115/50000
# 235/235 [==============================] - 14s 61ms/step - loss: 0.0146 - root_mean_squared_error: 0.1710 - val_loss: 0.0075 - val_root_mean_squared_error: 0.1223 - lr: 1.0000e-06
# Epoch 116/50000
# 235/235 [==============================] - 27s 114ms/step - loss: 0.0134 - root_mean_squared_error: 0.1635 - val_loss: 0.0071 - val_root_mean_squared_error: 0.1192 - lr: 1.0000e-06
# Epoch 117/50000
# 235/235 [==============================] - 27s 116ms/step - loss: 0.0146 - root_mean_squared_error: 0.1708 - val_loss: 0.0070 - val_root_mean_squared_error: 0.1180 - lr: 1.0000e-06
# Epoch 118/50000
# 235/235 [==============================] - 26s 112ms/step - loss: 0.0132 - root_mean_squared_error: 0.1626 - val_loss: 0.0075 - val_root_mean_squared_error: 0.1223 - lr: 1.0000e-06
# Epoch 119/50000
# 235/235 [==============================] - 998s 4s/step - loss: 0.0138 - root_mean_squared_error: 0.1662 - val_loss: 0.0071 - val_root_mean_squared_error: 0.1193 - lr: 1.0000e-06
# Epoch 120/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0146 - root_mean_squared_error: 0.1708 - val_loss: 0.0075 - val_root_mean_squared_error: 0.1228 - lr: 1.0000e-06
# Epoch 121/50000
# 235/235 [==============================] - 25s 107ms/step - loss: 0.0143 - root_mean_squared_error: 0.1694 - val_loss: 0.0074 - val_root_mean_squared_error: 0.1215 - lr: 1.0000e-06
# Epoch 122/50000
# 235/235 [==============================] - 26s 111ms/step - loss: 0.0135 - root_mean_squared_error: 0.1640 - val_loss: 0.0069 - val_root_mean_squared_error: 0.1177 - lr: 1.0000e-06
# Epoch 123/50000
# 235/235 [==============================] - 25s 108ms/step - loss: 0.0152 - root_mean_squared_error: 0.1746 - val_loss: 0.0068 - val_root_mean_squared_error: 0.1163 - lr: 1.0000e-06
# Epoch 124/50000
# 235/235 [==============================] - 26s 109ms/step - loss: 0.0152 - root_mean_squared_error: 0.1743 - val_loss: 0.0072 - val_root_mean_squared_error: 0.1200 - lr: 1.0000e-06
# Epoch 125/50000
# 235/235 [==============================] - 26s 109ms/step - loss: 0.0136 - root_mean_squared_error: 0.1647 - val_loss: 0.0071 - val_root_mean_squared_error: 0.1194 - lr: 1.0000e-07
# Epoch 126/50000
# 235/235 [==============================] - 26s 110ms/step - loss: 0.0144 - root_mean_squared_error: 0.1695 - val_loss: 0.0069 - val_root_mean_squared_error: 0.1176 - lr: 1.0000e-07
# Epoch 127/50000
# 235/235 [==============================] - 26s 109ms/step - loss: 0.0144 - root_mean_squared_error: 0.1697 - val_loss: 0.0072 - val_root_mean_squared_error: 0.1199 - lr: 1.0000e-07
# Epoch 128/50000
# 235/235 [==============================] - 25s 108ms/step - loss: 0.0137 - root_mean_squared_error: 0.1657 - val_loss: 0.0073 - val_root_mean_squared_error: 0.1207 - lr: 1.0000e-07
# Epoch 129/50000
# 235/235 [==============================] - 26s 109ms/step - loss: 0.0150 - root_mean_squared_error: 0.1735 - val_loss: 0.0076 - val_root_mean_squared_error: 0.1233 - lr: 1.0000e-07
# Epoch 130/50000
# 235/235 [==============================] - 25s 108ms/step - loss: 0.0135 - root_mean_squared_error: 0.1641 - val_loss: 0.0076 - val_root_mean_squared_error: 0.1237 - lr: 1.0000e-07
# Epoch 131/50000
# 235/235 [==============================] - 26s 110ms/step - loss: 0.0139 - root_mean_squared_error: 0.1667 - val_loss: 0.0070 - val_root_mean_squared_error: 0.1185 - lr: 1.0000e-07
# Epoch 132/50000
# 235/235 [==============================] - 26s 109ms/step - loss: 0.0144 - root_mean_squared_error: 0.1698 - val_loss: 0.0075 - val_root_mean_squared_error: 0.1225 - lr: 1.0000e-07
# Epoch 133/50000
# 235/235 [==============================] - 26s 110ms/step - loss: 0.0144 - root_mean_squared_error: 0.1698 - val_loss: 0.0075 - val_root_mean_squared_error: 0.1227 - lr: 1.0000e-07
# Epoch 134/50000
# 235/235 [==============================] - 26s 109ms/step - loss: 0.0135 - root_mean_squared_error: 0.1644 - val_loss: 0.0076 - val_root_mean_squared_error: 0.1236 - lr: 1.0000e-07
# Epoch 135/50000
# 235/235 [==============================] - 26s 109ms/step - loss: 0.0147 - root_mean_squared_error: 0.1717 - val_loss: 0.0070 - val_root_mean_squared_error: 0.1183 - lr: 1.0000e-07
# Epoch 136/50000
# 235/235 [==============================] - 26s 109ms/step - loss: 0.0149 - root_mean_squared_error: 0.1728 - val_loss: 0.0069 - val_root_mean_squared_error: 0.1173 - lr: 1.0000e-07
# Epoch 137/50000
# 235/235 [==============================] - 26s 109ms/step - loss: 0.0136 - root_mean_squared_error: 0.1652 - val_loss: 0.0070 - val_root_mean_squared_error: 0.1181 - lr: 1.0000e-07
# Epoch 138/50000
# 235/235 [==============================] - 25s 108ms/step - loss: 0.0150 - root_mean_squared_error: 0.1734 - val_loss: 0.0069 - val_root_mean_squared_error: 0.1179 - lr: 1.0000e-07
# Epoch 139/50000
# 235/235 [==============================] - 26s 109ms/step - loss: 0.0146 - root_mean_squared_error: 0.1711 - val_loss: 0.0080 - val_root_mean_squared_error: 0.1268 - lr: 1.0000e-07
# Epoch 140/50000
# 235/235 [==============================] - 26s 110ms/step - loss: 0.0142 - root_mean_squared_error: 0.1685 - val_loss: 0.0068 - val_root_mean_squared_error: 0.1170 - lr: 1.0000e-07
# Epoch 141/50000
# 235/235 [==============================] - 26s 109ms/step - loss: 0.0147 - root_mean_squared_error: 0.1715 - val_loss: 0.0061 - val_root_mean_squared_error: 0.1107 - lr: 1.0000e-07
# Epoch 142/50000
# 235/235 [==============================] - 26s 109ms/step - loss: 0.0144 - root_mean_squared_error: 0.1699 - val_loss: 0.0070 - val_root_mean_squared_error: 0.1185 - lr: 1.0000e-07
# Epoch 143/50000
# 235/235 [==============================] - 25s 108ms/step - loss: 0.0145 - root_mean_squared_error: 0.1704 - val_loss: 0.0070 - val_root_mean_squared_error: 0.1186 - lr: 1.0000e-07
# Epoch 144/50000
# 235/235 [==============================] - 26s 109ms/step - loss: 0.0141 - root_mean_squared_error: 0.1681 - val_loss: 0.0070 - val_root_mean_squared_error: 0.1182 - lr: 1.0000e-07
# Epoch 145/50000
# 235/235 [==============================] - 26s 109ms/step - loss: 0.0138 - root_mean_squared_error: 0.1663 - val_loss: 0.0072 - val_root_mean_squared_error: 0.1200 - lr: 1.0000e-08
# Epoch 146/50000
# 235/235 [==============================] - 25s 108ms/step - loss: 0.0147 - root_mean_squared_error: 0.1714 - val_loss: 0.0071 - val_root_mean_squared_error: 0.1190 - lr: 1.0000e-08
# Epoch 147/50000
# 235/235 [==============================] - 25s 108ms/step - loss: 0.0140 - root_mean_squared_error: 0.1670 - val_loss: 0.0068 - val_root_mean_squared_error: 0.1168 - lr: 1.0000e-08
# Epoch 148/50000
# 235/235 [==============================] - 25s 108ms/step - loss: 0.0144 - root_mean_squared_error: 0.1696 - val_loss: 0.0073 - val_root_mean_squared_error: 0.1212 - lr: 1.0000e-08
# Epoch 149/50000
# 235/235 [==============================] - 1083s 5s/step - loss: 0.0140 - root_mean_squared_error: 0.1674 - val_loss: 0.0071 - val_root_mean_squared_error: 0.1189 - lr: 1.0000e-08
# Epoch 150/50000
# 235/235 [==============================] - 11s 48ms/step - loss: 0.0158 - root_mean_squared_error: 0.1778 - val_loss: 0.0069 - val_root_mean_squared_error: 0.1175 - lr: 1.0000e-08
# Epoch 151/50000
# 235/235 [==============================] - 27s 114ms/step - loss: 0.0143 - root_mean_squared_error: 0.1693 - val_loss: 0.0077 - val_root_mean_squared_error: 0.1243 - lr: 1.0000e-08
# Epoch 152/50000
# 235/235 [==============================] - 26s 109ms/step - loss: 0.0140 - root_mean_squared_error: 0.1673 - val_loss: 0.0069 - val_root_mean_squared_error: 0.1175 - lr: 1.0000e-08
# Epoch 153/50000
# 235/235 [==============================] - 25s 108ms/step - loss: 0.0136 - root_mean_squared_error: 0.1649 - val_loss: 0.0077 - val_root_mean_squared_error: 0.1242 - lr: 1.0000e-08
# Epoch 154/50000
# 235/235 [==============================] - 25s 108ms/step - loss: 0.0148 - root_mean_squared_error: 0.1721 - val_loss: 0.0073 - val_root_mean_squared_error: 0.1209 - lr: 1.0000e-08
# Epoch 155/50000
# 235/235 [==============================] - 26s 109ms/step - loss: 0.0147 - root_mean_squared_error: 0.1715 - val_loss: 0.0083 - val_root_mean_squared_error: 0.1289 - lr: 1.0000e-08
# Epoch 156/50000
# 235/235 [==============================] - 25s 108ms/step - loss: 0.0136 - root_mean_squared_error: 0.1646 - val_loss: 0.0073 - val_root_mean_squared_error: 0.1207 - lr: 1.0000e-08
# Epoch 157/50000
# 235/235 [==============================] - 26s 109ms/step - loss: 0.0139 - root_mean_squared_error: 0.1670 - val_loss: 0.0067 - val_root_mean_squared_error: 0.1155 - lr: 1.0000e-08
# Epoch 158/50000
# 235/235 [==============================] - 26s 110ms/step - loss: 0.0138 - root_mean_squared_error: 0.1660 - val_loss: 0.0071 - val_root_mean_squared_error: 0.1193 - lr: 1.0000e-08
# Epoch 159/50000
# 235/235 [==============================] - 26s 110ms/step - loss: 0.0138 - root_mean_squared_error: 0.1663 - val_loss: 0.0071 - val_root_mean_squared_error: 0.1191 - lr: 1.0000e-08
# Epoch 160/50000
# 235/235 [==============================] - 26s 110ms/step - loss: 0.0143 - root_mean_squared_error: 0.1691 - val_loss: 0.0075 - val_root_mean_squared_error: 0.1227 - lr: 1.0000e-08
# Epoch 161/50000
# 235/235 [==============================] - 26s 109ms/step - loss: 0.0137 - root_mean_squared_error: 0.1656 - val_loss: 0.0070 - val_root_mean_squared_error: 0.1183 - lr: 1.0000e-08
# Epoch 162/50000
# 235/235 [==============================] - 26s 109ms/step - loss: 0.0144 - root_mean_squared_error: 0.1696 - val_loss: 0.0070 - val_root_mean_squared_error: 0.1186 - lr: 1.0000e-08
# Epoch 163/50000
# 235/235 [==============================] - 26s 109ms/step - loss: 0.0133 - root_mean_squared_error: 0.1634 - val_loss: 0.0076 - val_root_mean_squared_error: 0.1231 - lr: 1.0000e-08
# Epoch 164/50000
# 235/235 [==============================] - 26s 109ms/step - loss: 0.0138 - root_mean_squared_error: 0.1663 - val_loss: 0.0070 - val_root_mean_squared_error: 0.1182 - lr: 1.0000e-08
# Soil Temperature @ 15cm Depth (oC) [Catchment 3] Done
# Epoch 1/50000
# 235/235 [==============================] - 404s 2s/step - loss: 0.8298 - root_mean_squared_error: 1.7031 - val_loss: 1.1393 - val_root_mean_squared_error: 1.7777 - lr: 0.0010
# Epoch 2/50000
# 235/235 [==============================] - 8s 36ms/step - loss: 0.3955 - root_mean_squared_error: 0.9711 - val_loss: 0.9410 - val_root_mean_squared_error: 1.4893 - lr: 0.0010
# Epoch 3/50000
# 235/235 [==============================] - 27s 113ms/step - loss: 0.3053 - root_mean_squared_error: 0.8246 - val_loss: 0.4010 - val_root_mean_squared_error: 0.9351 - lr: 0.0010
# Epoch 4/50000
# 235/235 [==============================] - 26s 112ms/step - loss: 0.2511 - root_mean_squared_error: 0.7348 - val_loss: 0.1398 - val_root_mean_squared_error: 0.5303 - lr: 0.0010
# Epoch 5/50000
# 235/235 [==============================] - 26s 110ms/step - loss: 0.2195 - root_mean_squared_error: 0.6824 - val_loss: 0.6256 - val_root_mean_squared_error: 1.1936 - lr: 0.0010
# Epoch 6/50000
# 235/235 [==============================] - 26s 112ms/step - loss: 0.1993 - root_mean_squared_error: 0.6466 - val_loss: 0.0659 - val_root_mean_squared_error: 0.3642 - lr: 0.0010
# Epoch 7/50000
# 235/235 [==============================] - 26s 112ms/step - loss: 0.1729 - root_mean_squared_error: 0.5986 - val_loss: 1.0981 - val_root_mean_squared_error: 1.6237 - lr: 0.0010
# Epoch 8/50000
# 235/235 [==============================] - 26s 110ms/step - loss: 0.1502 - root_mean_squared_error: 0.5550 - val_loss: 0.0495 - val_root_mean_squared_error: 0.3146 - lr: 0.0010
# Epoch 9/50000
# 235/235 [==============================] - 26s 110ms/step - loss: 0.1423 - root_mean_squared_error: 0.5402 - val_loss: 1.2017 - val_root_mean_squared_error: 1.7402 - lr: 0.0010
# Epoch 10/50000
# 235/235 [==============================] - 26s 111ms/step - loss: 0.1285 - root_mean_squared_error: 0.5122 - val_loss: 0.0284 - val_root_mean_squared_error: 0.2386 - lr: 0.0010
# Epoch 11/50000
# 235/235 [==============================] - 26s 110ms/step - loss: 0.1150 - root_mean_squared_error: 0.4831 - val_loss: 1.2651 - val_root_mean_squared_error: 1.8036 - lr: 0.0010
# Epoch 12/50000
# 235/235 [==============================] - 968s 4s/step - loss: 0.1112 - root_mean_squared_error: 0.4743 - val_loss: 0.6879 - val_root_mean_squared_error: 1.2068 - lr: 0.0010
# Epoch 13/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.1038 - root_mean_squared_error: 0.4582 - val_loss: 0.0349 - val_root_mean_squared_error: 0.2643 - lr: 0.0010
# Epoch 14/50000
# 235/235 [==============================] - 26s 112ms/step - loss: 0.0952 - root_mean_squared_error: 0.4384 - val_loss: 0.4239 - val_root_mean_squared_error: 0.9275 - lr: 0.0010
# Epoch 15/50000
# 235/235 [==============================] - 26s 113ms/step - loss: 0.0910 - root_mean_squared_error: 0.4281 - val_loss: 0.6674 - val_root_mean_squared_error: 1.1786 - lr: 0.0010
# Epoch 16/50000
# 235/235 [==============================] - 26s 109ms/step - loss: 0.0850 - root_mean_squared_error: 0.4136 - val_loss: 0.1860 - val_root_mean_squared_error: 0.6126 - lr: 0.0010
# Epoch 17/50000
# 235/235 [==============================] - 26s 109ms/step - loss: 0.0809 - root_mean_squared_error: 0.4033 - val_loss: 0.1038 - val_root_mean_squared_error: 0.4557 - lr: 0.0010
# Epoch 18/50000
# 235/235 [==============================] - 927s 4s/step - loss: 0.0751 - root_mean_squared_error: 0.3882 - val_loss: 0.0269 - val_root_mean_squared_error: 0.2317 - lr: 0.0010
# Epoch 19/50000
# 235/235 [==============================] - 9s 36ms/step - loss: 0.0740 - root_mean_squared_error: 0.3861 - val_loss: 0.2217 - val_root_mean_squared_error: 0.6667 - lr: 0.0010
# Epoch 20/50000
# 235/235 [==============================] - 27s 115ms/step - loss: 0.0696 - root_mean_squared_error: 0.3738 - val_loss: 0.1362 - val_root_mean_squared_error: 0.5218 - lr: 0.0010
# Epoch 21/50000
# 235/235 [==============================] - 27s 115ms/step - loss: 0.0721 - root_mean_squared_error: 0.3808 - val_loss: 0.0382 - val_root_mean_squared_error: 0.2766 - lr: 0.0010
# Epoch 22/50000
# 235/235 [==============================] - 26s 113ms/step - loss: 0.0710 - root_mean_squared_error: 0.3778 - val_loss: 0.1522 - val_root_mean_squared_error: 0.5517 - lr: 0.0010
# Epoch 23/50000
# 235/235 [==============================] - 26s 110ms/step - loss: 0.0619 - root_mean_squared_error: 0.3526 - val_loss: 0.1757 - val_root_mean_squared_error: 0.5929 - lr: 0.0010
# Epoch 24/50000
# 235/235 [==============================] - 26s 109ms/step - loss: 0.0611 - root_mean_squared_error: 0.3501 - val_loss: 0.6142 - val_root_mean_squared_error: 1.1228 - lr: 0.0010
# Epoch 25/50000
# 235/235 [==============================] - 26s 109ms/step - loss: 0.0593 - root_mean_squared_error: 0.3447 - val_loss: 0.1393 - val_root_mean_squared_error: 0.5277 - lr: 0.0010
# Epoch 26/50000
# 235/235 [==============================] - 26s 109ms/step - loss: 0.0586 - root_mean_squared_error: 0.3426 - val_loss: 0.1703 - val_root_mean_squared_error: 0.5836 - lr: 0.0010
# Epoch 27/50000
# 235/235 [==============================] - 26s 109ms/step - loss: 0.0622 - root_mean_squared_error: 0.3532 - val_loss: 0.0474 - val_root_mean_squared_error: 0.3078 - lr: 0.0010
# Epoch 28/50000
# 235/235 [==============================] - 26s 109ms/step - loss: 0.0582 - root_mean_squared_error: 0.3417 - val_loss: 0.5771 - val_root_mean_squared_error: 1.0874 - lr: 0.0010
# Epoch 29/50000
# 235/235 [==============================] - 26s 111ms/step - loss: 0.0556 - root_mean_squared_error: 0.3339 - val_loss: 0.0136 - val_root_mean_squared_error: 0.1651 - lr: 0.0010
# Epoch 30/50000
# 235/235 [==============================] - 26s 110ms/step - loss: 0.0517 - root_mean_squared_error: 0.3217 - val_loss: 0.0904 - val_root_mean_squared_error: 0.4252 - lr: 0.0010
# Epoch 31/50000
# 235/235 [==============================] - 26s 109ms/step - loss: 0.0524 - root_mean_squared_error: 0.3240 - val_loss: 0.4344 - val_root_mean_squared_error: 0.9337 - lr: 0.0010
# Epoch 32/50000
# 235/235 [==============================] - 26s 109ms/step - loss: 0.0499 - root_mean_squared_error: 0.3160 - val_loss: 0.0377 - val_root_mean_squared_error: 0.2747 - lr: 0.0010
# Epoch 33/50000
# 235/235 [==============================] - 26s 109ms/step - loss: 0.0527 - root_mean_squared_error: 0.3247 - val_loss: 0.0274 - val_root_mean_squared_error: 0.2342 - lr: 0.0010
# Epoch 34/50000
# 235/235 [==============================] - 25s 108ms/step - loss: 0.0469 - root_mean_squared_error: 0.3065 - val_loss: 0.1231 - val_root_mean_squared_error: 0.4962 - lr: 0.0010
# Epoch 35/50000
# 235/235 [==============================] - 586s 3s/step - loss: 0.0499 - root_mean_squared_error: 0.3161 - val_loss: 0.1501 - val_root_mean_squared_error: 0.5481 - lr: 0.0010
# Epoch 36/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0470 - root_mean_squared_error: 0.3066 - val_loss: 0.1429 - val_root_mean_squared_error: 0.5346 - lr: 0.0010
# Epoch 37/50000
# 235/235 [==============================] - 22s 95ms/step - loss: 0.0476 - root_mean_squared_error: 0.3089 - val_loss: 0.0426 - val_root_mean_squared_error: 0.2920 - lr: 0.0010
# Epoch 38/50000
# 235/235 [==============================] - 29s 122ms/step - loss: 0.0479 - root_mean_squared_error: 0.3095 - val_loss: 0.2018 - val_root_mean_squared_error: 0.6353 - lr: 0.0010
# Epoch 39/50000
# 235/235 [==============================] - 27s 115ms/step - loss: 0.0463 - root_mean_squared_error: 0.3045 - val_loss: 0.0559 - val_root_mean_squared_error: 0.3344 - lr: 0.0010
# Epoch 40/50000
# 235/235 [==============================] - 26s 110ms/step - loss: 0.0461 - root_mean_squared_error: 0.3041 - val_loss: 0.1002 - val_root_mean_squared_error: 0.4476 - lr: 0.0010
# Epoch 41/50000
# 235/235 [==============================] - 26s 110ms/step - loss: 0.0420 - root_mean_squared_error: 0.2900 - val_loss: 0.0801 - val_root_mean_squared_error: 0.4002 - lr: 0.0010
# Epoch 42/50000
# 235/235 [==============================] - 26s 109ms/step - loss: 0.0460 - root_mean_squared_error: 0.3033 - val_loss: 0.0153 - val_root_mean_squared_error: 0.1749 - lr: 0.0010
# Epoch 43/50000
# 235/235 [==============================] - 26s 109ms/step - loss: 0.0432 - root_mean_squared_error: 0.2940 - val_loss: 0.1690 - val_root_mean_squared_error: 0.5813 - lr: 0.0010
# Epoch 44/50000
# 235/235 [==============================] - 26s 109ms/step - loss: 0.0415 - root_mean_squared_error: 0.2882 - val_loss: 0.0288 - val_root_mean_squared_error: 0.2401 - lr: 0.0010
# Epoch 45/50000
# 235/235 [==============================] - 26s 109ms/step - loss: 0.0409 - root_mean_squared_error: 0.2860 - val_loss: 0.0531 - val_root_mean_squared_error: 0.3259 - lr: 0.0010
# Epoch 46/50000
# 235/235 [==============================] - 187s 800ms/step - loss: 0.0380 - root_mean_squared_error: 0.2758 - val_loss: 0.0428 - val_root_mean_squared_error: 0.2926 - lr: 0.0010
# Epoch 47/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0383 - root_mean_squared_error: 0.2768 - val_loss: 0.1071 - val_root_mean_squared_error: 0.4629 - lr: 0.0010
# Epoch 48/50000
# 235/235 [==============================] - 21s 88ms/step - loss: 0.0402 - root_mean_squared_error: 0.2836 - val_loss: 0.2595 - val_root_mean_squared_error: 0.7205 - lr: 0.0010
# Epoch 49/50000
# 235/235 [==============================] - 28s 121ms/step - loss: 0.0393 - root_mean_squared_error: 0.2803 - val_loss: 0.1160 - val_root_mean_squared_error: 0.4816 - lr: 0.0010
# Epoch 50/50000
# 235/235 [==============================] - 27s 113ms/step - loss: 0.0248 - root_mean_squared_error: 0.2226 - val_loss: 0.0246 - val_root_mean_squared_error: 0.2216 - lr: 1.0000e-04
# Epoch 51/50000
# 235/235 [==============================] - 26s 111ms/step - loss: 0.0204 - root_mean_squared_error: 0.2021 - val_loss: 0.0092 - val_root_mean_squared_error: 0.1359 - lr: 1.0000e-04
# Epoch 52/50000
# 235/235 [==============================] - 26s 111ms/step - loss: 0.0191 - root_mean_squared_error: 0.1956 - val_loss: 0.0086 - val_root_mean_squared_error: 0.1312 - lr: 1.0000e-04
# Epoch 53/50000
# 235/235 [==============================] - 965s 4s/step - loss: 0.0209 - root_mean_squared_error: 0.2043 - val_loss: 0.0293 - val_root_mean_squared_error: 0.2421 - lr: 1.0000e-04
# Epoch 54/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0208 - root_mean_squared_error: 0.2042 - val_loss: 0.0113 - val_root_mean_squared_error: 0.1502 - lr: 1.0000e-04
# Epoch 55/50000
# 235/235 [==============================] - 19s 79ms/step - loss: 0.0191 - root_mean_squared_error: 0.1956 - val_loss: 0.0293 - val_root_mean_squared_error: 0.2422 - lr: 1.0000e-04
# Epoch 56/50000
# 235/235 [==============================] - 28s 117ms/step - loss: 0.0199 - root_mean_squared_error: 0.1996 - val_loss: 0.0294 - val_root_mean_squared_error: 0.2426 - lr: 1.0000e-04
# Epoch 57/50000
# 235/235 [==============================] - 26s 110ms/step - loss: 0.0187 - root_mean_squared_error: 0.1936 - val_loss: 0.0104 - val_root_mean_squared_error: 0.1446 - lr: 1.0000e-04
# Epoch 58/50000
# 235/235 [==============================] - 26s 110ms/step - loss: 0.0199 - root_mean_squared_error: 0.1998 - val_loss: 0.0079 - val_root_mean_squared_error: 0.1255 - lr: 1.0000e-04
# Epoch 59/50000
# 235/235 [==============================] - 26s 111ms/step - loss: 0.0194 - root_mean_squared_error: 0.1971 - val_loss: 0.0144 - val_root_mean_squared_error: 0.1698 - lr: 1.0000e-04
# Epoch 60/50000
# 235/235 [==============================] - 26s 109ms/step - loss: 0.0194 - root_mean_squared_error: 0.1969 - val_loss: 0.0088 - val_root_mean_squared_error: 0.1330 - lr: 1.0000e-04
# Epoch 61/50000
# 235/235 [==============================] - 26s 109ms/step - loss: 0.0186 - root_mean_squared_error: 0.1931 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1575 - lr: 1.0000e-04
# Epoch 62/50000
# 235/235 [==============================] - 26s 109ms/step - loss: 0.0188 - root_mean_squared_error: 0.1938 - val_loss: 0.0390 - val_root_mean_squared_error: 0.2793 - lr: 1.0000e-04
# Epoch 63/50000
# 235/235 [==============================] - 26s 110ms/step - loss: 0.0172 - root_mean_squared_error: 0.1853 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1898 - lr: 1.0000e-04
# Epoch 64/50000
# 235/235 [==============================] - 518s 2s/step - loss: 0.0183 - root_mean_squared_error: 0.1913 - val_loss: 0.0153 - val_root_mean_squared_error: 0.1747 - lr: 1.0000e-04
# Epoch 65/50000
# 235/235 [==============================] - 21s 90ms/step - loss: 0.0180 - root_mean_squared_error: 0.1900 - val_loss: 0.0226 - val_root_mean_squared_error: 0.2124 - lr: 1.0000e-04
# Epoch 66/50000
# 235/235 [==============================] - 836s 4s/step - loss: 0.0180 - root_mean_squared_error: 0.1900 - val_loss: 0.0174 - val_root_mean_squared_error: 0.1867 - lr: 1.0000e-04
# Epoch 67/50000
# 235/235 [==============================] - 10s 43ms/step - loss: 0.0178 - root_mean_squared_error: 0.1887 - val_loss: 0.0078 - val_root_mean_squared_error: 0.1251 - lr: 1.0000e-04
# Epoch 68/50000
# 235/235 [==============================] - 8s 35ms/step - loss: 0.0179 - root_mean_squared_error: 0.1892 - val_loss: 0.0079 - val_root_mean_squared_error: 0.1257 - lr: 1.0000e-04
# Epoch 69/50000
# 235/235 [==============================] - 8s 35ms/step - loss: 0.0178 - root_mean_squared_error: 0.1888 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1872 - lr: 1.0000e-04
# Epoch 70/50000
# 235/235 [==============================] - 8s 33ms/step - loss: 0.0187 - root_mean_squared_error: 0.1935 - val_loss: 0.0438 - val_root_mean_squared_error: 0.2960 - lr: 1.0000e-04
# Epoch 71/50000
# 129/235 [===============>..............] - ETA: 3s - loss: 0.0168 - root_mean_squared_error: 0.1831
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 162
#     154 early_stopping = EarlyStopping(monitor='val_loss', patience=100, restore_best_weights=True)  # Increased patience to 20
#     156 model1.compile(
#     157     loss=Huber(),  # Huber loss for better handling of outliers
#     158     optimizer=RMSprop(learning_rate=0.001),  # Lower learning rate
#     159     metrics=[RootMeanSquaredError()]
#     160 )
# --> 162 model1.fit(
#     163     x_train, y_train,
#     164     validation_data=(X_val, y_val),
#     165     epochs=50000,
#     166     callbacks=[cp, lr_scheduler, early_stopping],
#     167     verbose=1
#     168 )
#     170 farmData = pd.read_csv('Input.csv').ffill()  # Replace null values with the value from the previous row
#     171 predictdf = farmData[processed_columns]
#
# File /usr/local/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /usr/local/lib/python3.11/site-packages/keras/src/engine/training.py:1807, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1799 with tf.profiler.experimental.Trace(
#    1800     "train",
#    1801     epoch_num=epoch,
#    (...)
#    1804     _r=1,
#    1805 ):
#    1806     callbacks.on_train_batch_begin(step)
# -> 1807     tmp_logs = self.train_function(iterator)
#    1808     if data_handler.should_sync:
#    1809         context.async_wait()
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:832, in Function.__call__(self, *args, **kwds)
#     829 compiler = "xla" if self._jit_compile else "nonXla"
#     831 with OptionalXlaContext(self._jit_compile):
# --> 832   result = self._call(*args, **kwds)
#     834 new_tracing_count = self.experimental_get_tracing_count()
#     835 without_tracing = (tracing_count == new_tracing_count)
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:868, in Function._call(self, *args, **kwds)
#     865   self._lock.release()
#     866   # In this case we have created variables on the first call, so we run the
#     867   # defunned version which is guaranteed to never create variables.
# --> 868   return tracing_compilation.call_function(
#     869       args, kwds, self._no_variable_creation_config
#     870   )
#     871 elif self._variable_creation_config is not None:
#     872   # Release the lock early so that multiple threads can perform the call
#     873   # in parallel.
#     874   self._lock.release()
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1323, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1319 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1320 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1321     and executing_eagerly):
#    1322   # No tape is watching; skip to running the function.
# -> 1323   return self._inference_function.call_preflattened(args)
#    1324 forward_backward = self._select_forward_and_backward_functions(
#    1325     args,
#    1326     possible_gradient_type,
#    1327     executing_eagerly)
#    1328 forward_function, args_with_tangents = forward_backward.forward()
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/eager/context.py:1486, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1484 cancellation_context = cancellation.context()
#    1485 if cancellation_context is None:
# -> 1486   outputs = execute.execute(
#    1487       name.decode("utf-8"),
#    1488       num_outputs=num_outputs,
#    1489       inputs=tensor_inputs,
#    1490       attrs=attrs,
#    1491       ctx=self,
#    1492   )
#    1493 else:
#    1494   outputs = execute.execute_with_cancellation(
#    1495       name.decode("utf-8"),
#    1496       num_outputs=num_outputs,
#    (...)
#    1500       cancellation_manager=cancellation_context,
#    1501   )
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
# Load the last trained model
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt

# Define the path to the last trained model
last_model_path = 'Models/' + sensor + '.keras'

# Load the model
model = load_model(last_model_path)

# Evaluate the model on the test set
test_loss, test_rmse = model.evaluate(X_test, y_test, verbose=1)
print(f"Test Loss: {test_loss}")
print(f"Test RMSE: {test_rmse}")

# Make predictions on the test set
y_pred = model.predict(X_test)

# Plot the true vs predicted values
plt.figure(figsize=(10, 6))
plt.plot(y_test, label='True Values', alpha=0.7)
plt.plot(y_pred, label='Predicted Values', alpha=0.7)
plt.title('True vs Predicted Values')
plt.xlabel('Sample Index')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
import os 
import pandas as pd
import numpy as np  
import tensorflow as tf  
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import InputLayer, LSTM, Dense, Dropout, BatchNormalization, Bidirectional
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.losses import Huber
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.metrics import RootMeanSquaredError  

# Function to normalize a string by removing non-alphanumeric characters
def normalize_string(s):
    return ''.join(e for e in s if e.isalnum())

# Function to get columns from DataFrame that match a given sensor
def get_matching_columns(df, sensor):
    matching_columns = []
    for col in df.columns:
        processed_col_name = col
        if sensor.lower() in processed_col_name.lower():
            matching_columns.append(col)
    return matching_columns

window_size = 5  # Define the window size for the data

# Function to convert DataFrame to input (X) and output (y) arrays for the model
def df_to_X_y(df, window_size, Sensor, output_weight=1.5):
    df_as_np = df.to_numpy()  # Convert DataFrame to numpy array
    x = []  # Initialize list for input data
    y = []  # Initialize list for output data

    # Get columns that match the sensor
    matching_columns = get_matching_columns(df, Sensor)
        
    if matching_columns:
        myColumn = df.columns.get_loc(matching_columns[-1])  # Get the index of the last matching column
    else:
        print('No matching column found for Sensor:', Sensor)
        return None, None

    for i in range(len(df_as_np) - window_size):
        row = df_as_np[i:i+window_size].copy()  # Include all columns in the input window
        x.append(row)
        label = df_as_np[i+window_size][myColumn]  # Get the label for the window
        y.append(label)

    return np.array(x), np.array(y)

# Read the input data
df = pd.read_csv('Input.csv')  # Read the CSV file into a DataFrame
df = df.ffill()  # Replace null values with the value from the previous row
df = df.select_dtypes(include=[np.number])  # Keep only numeric columns
df.to_csv('fileA.csv', sep=',', encoding='utf-8', index=False, float_format='%.2f')  # Save the unedited input CSV
df.to_csv('fileB.csv', sep=',', encoding='utf-8', index=False, float_format='%.2f')  # Save the comparison CSV
df.to_csv('fileC.csv', sep=',', encoding='utf-8', index=False, float_format='%.2f')
df.to_csv('fileD.csv', sep=',', encoding='utf-8', index=False, float_format='%.2f')  # Save the CSV with model-generated values

# Loop through each sensor (column) in the DataFrame
for sensor in df.columns:
    print(f"Processing sensor: {sensor}")

    # Prepare data for the current sensor
    x, y = df_to_X_y(df, window_size, Sensor=sensor)  # Use df_to_X_y to create inputs and outputs
    if x is None or y is None:
        print(f"Skipping sensor {sensor} due to missing data.")
        continue

    inputsize = x.shape[1:]  # Get the input size
    outputsize = y.shape[1:]  # Get the output size

    x = np.asarray(x).astype('float32')  # Ensure x contains only numeric data types
    y = np.asarray(y).astype('float32')

    trainSplit = round(x.shape[0] * 0.75)  # Set the training split
    valSplit = round(x.shape[0] * 0.9)  # Set the validation split
    x_train, y_train = x[:trainSplit], y[:trainSplit]
    X_val, y_val = x[trainSplit:valSplit], y[trainSplit:valSplit]
    X_test, y_test = x[valSplit:], y[valSplit:]

    x_train = tf.convert_to_tensor(x_train, dtype=tf.float32)
    y_train = tf.convert_to_tensor(y_train, dtype=tf.float32)
    X_val = tf.convert_to_tensor(X_val, dtype=tf.float32)
    y_val = tf.convert_to_tensor(y_val, dtype=tf.float32)

    # Define the model
    model1 = Sequential()

    # Input layer
    model1.add(InputLayer((inputsize)))

    # Bidirectional LSTM layers
    model1.add(Bidirectional(LSTM(256, return_sequences=True)))  # Bidirectional LSTM
    model1.add(Dropout(0.5))  # Increased dropout for better regularization
    model1.add(Bidirectional(LSTM(128)))  # Second Bidirectional LSTM
    model1.add(Dropout(0.5))

    # Batch normalization for faster convergence
    model1.add(BatchNormalization())

    # Fully connected layers
    model1.add(Dense(64, activation='relu'))  # Added another dense layer
    model1.add(Dense(16, activation='relu'))  # Added another dense layer
    model1.add(Dense(8, activation='relu'))  # Added another dense layer
    model1.add(Dense(1, activation='linear'))  # Output layer

    # Compile the model
    cp = ModelCheckpoint('Models/' + sensor + '.keras', save_best_only=True)
    lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=20, min_lr=1e-25)  # Increased patience to 10
    early_stopping = EarlyStopping(monitor='val_loss', patience=100, restore_best_weights=True)  # Increased patience to 20

    model1.compile(
        loss=Huber(),  # Huber loss for better handling of outliers
        optimizer=RMSprop(learning_rate=0.001),  # Lower learning rate
        metrics=[RootMeanSquaredError()]
    )

    model1.fit(
        x_train, y_train,
        validation_data=(X_val, y_val),
        epochs=50000,
        callbacks=[cp, lr_scheduler, early_stopping],
        verbose=1
    )

    farmData = pd.read_csv('Input.csv').ffill()  # Replace null values with the value from the previous row
    predictdf = farmData[df.columns]
    I = predictdf.columns.get_loc(sensor)

    comparison_df = pd.read_csv('fileC.csv').astype('object')
    farmData = pd.read_csv('fileB.csv').astype('object')
    replaced_df = pd.read_csv('fileD.csv').astype('object')
    new_df = replaced_df.copy()

    for k in range(len(farmData) - window_size):
        try:
            X, y = df_to_X_y(predictdf, window_size, sensor)
            predX = model1.predict(X[k:k+1].astype('float32'), verbose=0)
            nbr = predX[0][0]
        except Exception as e:
            print(sensor + ' prediction error')
            print(e)
        
        try:
            if farmData.iloc[k+window_size, I+2] != 'Acceptable':
                farmData.iat[k+window_size, I+2] = 'Infilled'
                farmData.iat[k+window_size, I+1] = nbr
                comparison_df.iat[k+window_size, I+2] = 'Infilled'
                comparison_df.iat[k+window_size, I+1] = nbr  
                replaced_df.iat[k+window_size, I+2] = 'Infilled'
                replaced_df.iat[k+window_size, I+1] = nbr  
                predictdf.iat[k+window_size, I] = nbr  
        except Exception as e:
            print(sensor + ' data error')
            print(e)

        try:
            if abs(nbr-farmData.iat[k+window_size, I+1])/farmData.iat[k+window_size, I+1] > 0.05:
                comparison_df.iat[k+window_size, I+2] = 'uncertain'
                replaced_df.iat[k+window_size, I+2] = 'uncertain'
        except Exception as e:
            print(sensor + ' comparison error')
            print(e)

        try:
            if replaced_df.iat[k+window_size, I+2] == 'uncertain':
                replaced_df.iat[k+window_size, I+1] = nbr
                replaced_df.iat[k+window_size, I+2] = 'Replaced'
        except Exception as e:
            print(sensor + ' replacement error')
            print(e)

        try:
            new_df.iat[k+window_size, I+1] = nbr
        except Exception as e:            
            print(sensor + ' new error')
            print(e)
    df.to_csv('fileA.csv', sep=',', encoding='utf-8', index=False, float_format='%.2f')
    farmData.to_csv('fileB.csv', sep=',', encoding='utf-8', index=False, float_format='%.2f')
    comparison_df.to_csv('fileC.csv', sep=',', encoding='utf-8', index=False, float_format='%.2f')
    replaced_df.to_csv('fileD.csv', sep=',', encoding='utf-8', index=False, float_format='%.2f')
    new_df.to_csv('fileE.csv', sep=',', encoding='utf-8', index=False, float_format='%.2f')

    print(sensor + ' Done')
# Out:
# Processing sensor: Flow (l/s) [Catchment 1]
# Epoch 1/50000
# 235/235 [==============================] - 14s 37ms/step - loss: 0.2452 - root_mean_squared_error: 0.8834 - val_loss: 1.0878 - val_root_mean_squared_error: 1.9652 - lr: 0.0010
# Epoch 2/50000
# 235/235 [==============================] - 7s 31ms/step - loss: 0.1172 - root_mean_squared_error: 0.5336 - val_loss: 0.7761 - val_root_mean_squared_error: 1.5551 - lr: 0.0010
# Epoch 3/50000
# 235/235 [==============================] - 8s 34ms/step - loss: 0.0949 - root_mean_squared_error: 0.4750 - val_loss: 0.5896 - val_root_mean_squared_error: 1.2450 - lr: 0.0010
# Epoch 4/50000
# 235/235 [==============================] - 8s 33ms/step - loss: 0.0831 - root_mean_squared_error: 0.4436 - val_loss: 0.4158 - val_root_mean_squared_error: 1.0340 - lr: 0.0010
# Epoch 5/50000
# 235/235 [==============================] - 7s 31ms/step - loss: 0.0725 - root_mean_squared_error: 0.4109 - val_loss: 0.4198 - val_root_mean_squared_error: 1.0391 - lr: 0.0010
# Epoch 6/50000
# 235/235 [==============================] - 8s 32ms/step - loss: 0.0679 - root_mean_squared_error: 0.3956 - val_loss: 0.5099 - val_root_mean_squared_error: 1.1136 - lr: 0.0010
# Epoch 7/50000
# 235/235 [==============================] - 7s 32ms/step - loss: 0.0629 - root_mean_squared_error: 0.3787 - val_loss: 0.1736 - val_root_mean_squared_error: 0.6766 - lr: 0.0010
# Epoch 8/50000
# 235/235 [==============================] - 7s 31ms/step - loss: 0.0590 - root_mean_squared_error: 0.3696 - val_loss: 0.1828 - val_root_mean_squared_error: 0.7170 - lr: 0.0010
# Epoch 9/50000
# 235/235 [==============================] - 8s 32ms/step - loss: 0.0558 - root_mean_squared_error: 0.3584 - val_loss: 0.2389 - val_root_mean_squared_error: 0.7588 - lr: 0.0010
# Epoch 10/50000
# 235/235 [==============================] - 8s 33ms/step - loss: 0.0575 - root_mean_squared_error: 0.3635 - val_loss: 0.2879 - val_root_mean_squared_error: 0.8154 - lr: 0.0010
# Epoch 11/50000
# 235/235 [==============================] - 8s 32ms/step - loss: 0.0525 - root_mean_squared_error: 0.3488 - val_loss: 0.3510 - val_root_mean_squared_error: 1.0548 - lr: 0.0010
# Epoch 12/50000
# 235/235 [==============================] - 8s 32ms/step - loss: 0.0547 - root_mean_squared_error: 0.3576 - val_loss: 0.2378 - val_root_mean_squared_error: 0.7477 - lr: 0.0010
# Epoch 13/50000
# 235/235 [==============================] - 8s 32ms/step - loss: 0.0503 - root_mean_squared_error: 0.3325 - val_loss: 0.1676 - val_root_mean_squared_error: 0.6348 - lr: 0.0010
# Epoch 14/50000
# 235/235 [==============================] - 8s 32ms/step - loss: 0.0479 - root_mean_squared_error: 0.3274 - val_loss: 0.4610 - val_root_mean_squared_error: 1.1299 - lr: 0.0010
# Epoch 15/50000
# 235/235 [==============================] - 7s 31ms/step - loss: 0.0467 - root_mean_squared_error: 0.3218 - val_loss: 0.3040 - val_root_mean_squared_error: 0.8748 - lr: 0.0010
# Epoch 16/50000
# 235/235 [==============================] - 7s 32ms/step - loss: 0.0454 - root_mean_squared_error: 0.3203 - val_loss: 0.4148 - val_root_mean_squared_error: 1.0219 - lr: 0.0010
# Epoch 17/50000
# 235/235 [==============================] - 8s 33ms/step - loss: 0.0473 - root_mean_squared_error: 0.3270 - val_loss: 0.2733 - val_root_mean_squared_error: 0.7799 - lr: 0.0010
# Epoch 18/50000
# 235/235 [==============================] - 8s 33ms/step - loss: 0.0436 - root_mean_squared_error: 0.3165 - val_loss: 0.1786 - val_root_mean_squared_error: 0.6516 - lr: 0.0010
# Epoch 19/50000
# 235/235 [==============================] - 8s 33ms/step - loss: 0.0412 - root_mean_squared_error: 0.3081 - val_loss: 0.1486 - val_root_mean_squared_error: 0.6056 - lr: 0.0010
# Epoch 20/50000
# 235/235 [==============================] - 8s 34ms/step - loss: 0.0423 - root_mean_squared_error: 0.3115 - val_loss: 0.3166 - val_root_mean_squared_error: 0.9416 - lr: 0.0010
# Epoch 21/50000
# 235/235 [==============================] - 8s 35ms/step - loss: 0.0406 - root_mean_squared_error: 0.3025 - val_loss: 0.2127 - val_root_mean_squared_error: 0.7128 - lr: 0.0010
# Epoch 22/50000
# 235/235 [==============================] - 8s 33ms/step - loss: 0.0426 - root_mean_squared_error: 0.3136 - val_loss: 0.1206 - val_root_mean_squared_error: 0.5447 - lr: 0.0010
# Epoch 23/50000
# 235/235 [==============================] - 7s 31ms/step - loss: 0.0418 - root_mean_squared_error: 0.3113 - val_loss: 0.1374 - val_root_mean_squared_error: 0.6358 - lr: 0.0010
# Epoch 24/50000
# 235/235 [==============================] - 7s 31ms/step - loss: 0.0436 - root_mean_squared_error: 0.3197 - val_loss: 0.2724 - val_root_mean_squared_error: 0.8408 - lr: 0.0010
# Epoch 25/50000
# 235/235 [==============================] - 8s 33ms/step - loss: 0.0403 - root_mean_squared_error: 0.2986 - val_loss: 0.1731 - val_root_mean_squared_error: 0.7462 - lr: 0.0010
# Epoch 26/50000
# 235/235 [==============================] - 7s 32ms/step - loss: 0.0401 - root_mean_squared_error: 0.3013 - val_loss: 0.1816 - val_root_mean_squared_error: 0.7041 - lr: 0.0010
# Epoch 27/50000
# 235/235 [==============================] - 8s 33ms/step - loss: 0.0403 - root_mean_squared_error: 0.3077 - val_loss: 0.1626 - val_root_mean_squared_error: 0.6468 - lr: 0.0010
# Epoch 28/50000
# 235/235 [==============================] - 8s 33ms/step - loss: 0.0372 - root_mean_squared_error: 0.2910 - val_loss: 0.4765 - val_root_mean_squared_error: 1.0288 - lr: 0.0010
# Epoch 29/50000
# 235/235 [==============================] - 8s 33ms/step - loss: 0.0386 - root_mean_squared_error: 0.3009 - val_loss: 0.2659 - val_root_mean_squared_error: 0.8258 - lr: 0.0010
# Epoch 30/50000
# 235/235 [==============================] - 8s 34ms/step - loss: 0.0353 - root_mean_squared_error: 0.2845 - val_loss: 0.1764 - val_root_mean_squared_error: 0.7037 - lr: 0.0010
# Epoch 31/50000
# 235/235 [==============================] - 8s 32ms/step - loss: 0.0351 - root_mean_squared_error: 0.2823 - val_loss: 0.1131 - val_root_mean_squared_error: 0.5243 - lr: 0.0010
# Epoch 32/50000
# 235/235 [==============================] - 8s 33ms/step - loss: 0.0341 - root_mean_squared_error: 0.2780 - val_loss: 0.1322 - val_root_mean_squared_error: 0.5917 - lr: 0.0010
# Epoch 33/50000
# 235/235 [==============================] - 8s 33ms/step - loss: 0.0353 - root_mean_squared_error: 0.2850 - val_loss: 0.2156 - val_root_mean_squared_error: 0.7276 - lr: 0.0010
# Epoch 34/50000
# 235/235 [==============================] - 8s 34ms/step - loss: 0.0346 - root_mean_squared_error: 0.2801 - val_loss: 0.3162 - val_root_mean_squared_error: 0.8304 - lr: 0.0010
# Epoch 35/50000
# 235/235 [==============================] - 8s 35ms/step - loss: 0.0349 - root_mean_squared_error: 0.2840 - val_loss: 0.1353 - val_root_mean_squared_error: 0.5611 - lr: 0.0010
# Epoch 36/50000
# 235/235 [==============================] - 8s 32ms/step - loss: 0.0338 - root_mean_squared_error: 0.2758 - val_loss: 0.2065 - val_root_mean_squared_error: 0.6788 - lr: 0.0010
# Epoch 37/50000
# 235/235 [==============================] - 8s 33ms/step - loss: 0.0351 - root_mean_squared_error: 0.2794 - val_loss: 0.1227 - val_root_mean_squared_error: 0.5308 - lr: 0.0010
# Epoch 38/50000
# 235/235 [==============================] - 8s 33ms/step - loss: 0.0338 - root_mean_squared_error: 0.2755 - val_loss: 0.1160 - val_root_mean_squared_error: 0.5132 - lr: 0.0010
# Epoch 39/50000
# 235/235 [==============================] - 7s 32ms/step - loss: 0.0324 - root_mean_squared_error: 0.2718 - val_loss: 0.2889 - val_root_mean_squared_error: 0.7895 - lr: 0.0010
# Epoch 40/50000
# 235/235 [==============================] - 7s 31ms/step - loss: 0.0319 - root_mean_squared_error: 0.2653 - val_loss: 0.1319 - val_root_mean_squared_error: 0.5760 - lr: 0.0010
# Epoch 41/50000
# 235/235 [==============================] - 7s 31ms/step - loss: 0.0324 - root_mean_squared_error: 0.2679 - val_loss: 0.1204 - val_root_mean_squared_error: 0.6230 - lr: 0.0010
# Epoch 42/50000
# 235/235 [==============================] - 8s 33ms/step - loss: 0.0331 - root_mean_squared_error: 0.2750 - val_loss: 0.0708 - val_root_mean_squared_error: 0.4288 - lr: 0.0010
# Epoch 43/50000
# 235/235 [==============================] - 8s 33ms/step - loss: 0.0305 - root_mean_squared_error: 0.2634 - val_loss: 0.1731 - val_root_mean_squared_error: 0.6950 - lr: 0.0010
# Epoch 44/50000
# 235/235 [==============================] - 8s 36ms/step - loss: 0.0300 - root_mean_squared_error: 0.2612 - val_loss: 0.1618 - val_root_mean_squared_error: 0.6271 - lr: 0.0010
# Epoch 45/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0310 - root_mean_squared_error: 0.2658 - val_loss: 0.2555 - val_root_mean_squared_error: 0.9234 - lr: 0.0010
# Epoch 46/50000
# 235/235 [==============================] - 8s 34ms/step - loss: 0.0311 - root_mean_squared_error: 0.2661 - val_loss: 0.1280 - val_root_mean_squared_error: 0.5614 - lr: 0.0010
# Epoch 47/50000
# 235/235 [==============================] - 8s 34ms/step - loss: 0.0301 - root_mean_squared_error: 0.2658 - val_loss: 0.2042 - val_root_mean_squared_error: 0.6948 - lr: 0.0010
# Epoch 48/50000
# 235/235 [==============================] - 7s 31ms/step - loss: 0.0300 - root_mean_squared_error: 0.2630 - val_loss: 0.1486 - val_root_mean_squared_error: 0.6318 - lr: 0.0010
# Epoch 49/50000
# 235/235 [==============================] - 7s 31ms/step - loss: 0.0308 - root_mean_squared_error: 0.2643 - val_loss: 0.1119 - val_root_mean_squared_error: 0.5682 - lr: 0.0010
# Epoch 50/50000
# 235/235 [==============================] - 7s 31ms/step - loss: 0.0291 - root_mean_squared_error: 0.2585 - val_loss: 0.1147 - val_root_mean_squared_error: 0.5415 - lr: 0.0010
# Epoch 51/50000
# 235/235 [==============================] - 8s 32ms/step - loss: 0.0286 - root_mean_squared_error: 0.2565 - val_loss: 0.0802 - val_root_mean_squared_error: 0.4572 - lr: 0.0010
# Epoch 52/50000
# 235/235 [==============================] - 7s 32ms/step - loss: 0.0301 - root_mean_squared_error: 0.2645 - val_loss: 0.2188 - val_root_mean_squared_error: 0.7609 - lr: 0.0010
# Epoch 53/50000
# 235/235 [==============================] - 8s 36ms/step - loss: 0.0276 - root_mean_squared_error: 0.2501 - val_loss: 0.1168 - val_root_mean_squared_error: 0.5412 - lr: 0.0010
# Epoch 54/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0265 - root_mean_squared_error: 0.2442 - val_loss: 0.0902 - val_root_mean_squared_error: 0.4882 - lr: 0.0010
# Epoch 55/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0292 - root_mean_squared_error: 0.2557 - val_loss: 0.0810 - val_root_mean_squared_error: 0.4354 - lr: 0.0010
# Epoch 56/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0285 - root_mean_squared_error: 0.2553 - val_loss: 0.2401 - val_root_mean_squared_error: 0.7698 - lr: 0.0010
# Epoch 57/50000
# 235/235 [==============================] - 7s 31ms/step - loss: 0.0273 - root_mean_squared_error: 0.2510 - val_loss: 0.0924 - val_root_mean_squared_error: 0.4786 - lr: 0.0010
# Epoch 58/50000
# 235/235 [==============================] - 7s 31ms/step - loss: 0.0273 - root_mean_squared_error: 0.2478 - val_loss: 0.1519 - val_root_mean_squared_error: 0.5845 - lr: 0.0010
# Epoch 59/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0285 - root_mean_squared_error: 0.2546 - val_loss: 0.1081 - val_root_mean_squared_error: 0.5267 - lr: 0.0010
# Epoch 60/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0257 - root_mean_squared_error: 0.2389 - val_loss: 0.1425 - val_root_mean_squared_error: 0.6141 - lr: 0.0010
# Epoch 61/50000
# 235/235 [==============================] - 7s 28ms/step - loss: 0.0275 - root_mean_squared_error: 0.2514 - val_loss: 0.1076 - val_root_mean_squared_error: 0.5301 - lr: 0.0010
# Epoch 62/50000
# 235/235 [==============================] - 7s 28ms/step - loss: 0.0267 - root_mean_squared_error: 0.2419 - val_loss: 0.2156 - val_root_mean_squared_error: 0.7069 - lr: 0.0010
# Epoch 63/50000
# 235/235 [==============================] - 7s 28ms/step - loss: 0.0217 - root_mean_squared_error: 0.2275 - val_loss: 0.1098 - val_root_mean_squared_error: 0.5275 - lr: 1.0000e-04
# Epoch 64/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0188 - root_mean_squared_error: 0.2093 - val_loss: 0.0966 - val_root_mean_squared_error: 0.4892 - lr: 1.0000e-04
# Epoch 65/50000
# 235/235 [==============================] - 7s 28ms/step - loss: 0.0178 - root_mean_squared_error: 0.1998 - val_loss: 0.1132 - val_root_mean_squared_error: 0.5221 - lr: 1.0000e-04
# Epoch 66/50000
# 235/235 [==============================] - 7s 28ms/step - loss: 0.0172 - root_mean_squared_error: 0.1968 - val_loss: 0.1150 - val_root_mean_squared_error: 0.5339 - lr: 1.0000e-04
# Epoch 67/50000
# 235/235 [==============================] - 7s 28ms/step - loss: 0.0167 - root_mean_squared_error: 0.1949 - val_loss: 0.0828 - val_root_mean_squared_error: 0.4469 - lr: 1.0000e-04
# Epoch 68/50000
# 235/235 [==============================] - 7s 28ms/step - loss: 0.0179 - root_mean_squared_error: 0.2061 - val_loss: 0.0994 - val_root_mean_squared_error: 0.4925 - lr: 1.0000e-04
# Epoch 69/50000
# 235/235 [==============================] - 7s 28ms/step - loss: 0.0186 - root_mean_squared_error: 0.2116 - val_loss: 0.0789 - val_root_mean_squared_error: 0.4365 - lr: 1.0000e-04
# Epoch 70/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0160 - root_mean_squared_error: 0.1891 - val_loss: 0.0997 - val_root_mean_squared_error: 0.5017 - lr: 1.0000e-04
# Epoch 71/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0157 - root_mean_squared_error: 0.1915 - val_loss: 0.0970 - val_root_mean_squared_error: 0.4774 - lr: 1.0000e-04
# Epoch 72/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0166 - root_mean_squared_error: 0.1947 - val_loss: 0.1176 - val_root_mean_squared_error: 0.5369 - lr: 1.0000e-04
# Epoch 73/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0161 - root_mean_squared_error: 0.1896 - val_loss: 0.1000 - val_root_mean_squared_error: 0.5116 - lr: 1.0000e-04
# Epoch 74/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0154 - root_mean_squared_error: 0.1874 - val_loss: 0.1099 - val_root_mean_squared_error: 0.5322 - lr: 1.0000e-04
# Epoch 75/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0146 - root_mean_squared_error: 0.1799 - val_loss: 0.0975 - val_root_mean_squared_error: 0.4900 - lr: 1.0000e-04
# Epoch 76/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0162 - root_mean_squared_error: 0.1881 - val_loss: 0.0921 - val_root_mean_squared_error: 0.4787 - lr: 1.0000e-04
# Epoch 77/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0155 - root_mean_squared_error: 0.1845 - val_loss: 0.1036 - val_root_mean_squared_error: 0.5182 - lr: 1.0000e-04
# Epoch 78/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0166 - root_mean_squared_error: 0.1939 - val_loss: 0.0934 - val_root_mean_squared_error: 0.4895 - lr: 1.0000e-04
# Epoch 79/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0157 - root_mean_squared_error: 0.1871 - val_loss: 0.1045 - val_root_mean_squared_error: 0.5076 - lr: 1.0000e-04
# Epoch 80/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0162 - root_mean_squared_error: 0.1928 - val_loss: 0.1040 - val_root_mean_squared_error: 0.5085 - lr: 1.0000e-04
# Epoch 81/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0155 - root_mean_squared_error: 0.1870 - val_loss: 0.0824 - val_root_mean_squared_error: 0.4549 - lr: 1.0000e-04
# Epoch 82/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0161 - root_mean_squared_error: 0.1938 - val_loss: 0.1036 - val_root_mean_squared_error: 0.4966 - lr: 1.0000e-04
# Epoch 83/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0152 - root_mean_squared_error: 0.1876 - val_loss: 0.0937 - val_root_mean_squared_error: 0.4809 - lr: 1.0000e-05
# Epoch 84/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0151 - root_mean_squared_error: 0.1863 - val_loss: 0.0953 - val_root_mean_squared_error: 0.4854 - lr: 1.0000e-05
# Epoch 85/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0159 - root_mean_squared_error: 0.1905 - val_loss: 0.0930 - val_root_mean_squared_error: 0.4820 - lr: 1.0000e-05
# Epoch 86/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0146 - root_mean_squared_error: 0.1795 - val_loss: 0.0977 - val_root_mean_squared_error: 0.4933 - lr: 1.0000e-05
# Epoch 87/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0155 - root_mean_squared_error: 0.1851 - val_loss: 0.0950 - val_root_mean_squared_error: 0.4897 - lr: 1.0000e-05
# Epoch 88/50000
# 235/235 [==============================] - 7s 28ms/step - loss: 0.0138 - root_mean_squared_error: 0.1730 - val_loss: 0.0956 - val_root_mean_squared_error: 0.4890 - lr: 1.0000e-05
# Epoch 89/50000
# 235/235 [==============================] - 7s 28ms/step - loss: 0.0154 - root_mean_squared_error: 0.1903 - val_loss: 0.0938 - val_root_mean_squared_error: 0.4872 - lr: 1.0000e-05
# Epoch 90/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0145 - root_mean_squared_error: 0.1800 - val_loss: 0.0967 - val_root_mean_squared_error: 0.4934 - lr: 1.0000e-05
# Epoch 91/50000
# 235/235 [==============================] - 7s 28ms/step - loss: 0.0146 - root_mean_squared_error: 0.1818 - val_loss: 0.0956 - val_root_mean_squared_error: 0.4882 - lr: 1.0000e-05
# Epoch 92/50000
# 235/235 [==============================] - 7s 28ms/step - loss: 0.0153 - root_mean_squared_error: 0.1905 - val_loss: 0.0976 - val_root_mean_squared_error: 0.4986 - lr: 1.0000e-05
# Epoch 93/50000
# 235/235 [==============================] - 7s 28ms/step - loss: 0.0141 - root_mean_squared_error: 0.1759 - val_loss: 0.0988 - val_root_mean_squared_error: 0.5044 - lr: 1.0000e-05
# Epoch 94/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0148 - root_mean_squared_error: 0.1805 - val_loss: 0.0963 - val_root_mean_squared_error: 0.4991 - lr: 1.0000e-05
# Epoch 95/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0149 - root_mean_squared_error: 0.1819 - val_loss: 0.0952 - val_root_mean_squared_error: 0.4932 - lr: 1.0000e-05
# Epoch 96/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0150 - root_mean_squared_error: 0.1861 - val_loss: 0.0929 - val_root_mean_squared_error: 0.4860 - lr: 1.0000e-05
# Epoch 97/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0147 - root_mean_squared_error: 0.1837 - val_loss: 0.0982 - val_root_mean_squared_error: 0.5059 - lr: 1.0000e-05
# Epoch 98/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0139 - root_mean_squared_error: 0.1749 - val_loss: 0.0973 - val_root_mean_squared_error: 0.5019 - lr: 1.0000e-05
# Epoch 99/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0143 - root_mean_squared_error: 0.1785 - val_loss: 0.0982 - val_root_mean_squared_error: 0.5001 - lr: 1.0000e-05
# Epoch 100/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0151 - root_mean_squared_error: 0.1863 - val_loss: 0.0966 - val_root_mean_squared_error: 0.4990 - lr: 1.0000e-05
# Epoch 101/50000
# 235/235 [==============================] - 7s 31ms/step - loss: 0.0147 - root_mean_squared_error: 0.1817 - val_loss: 0.0986 - val_root_mean_squared_error: 0.5042 - lr: 1.0000e-05
# Epoch 102/50000
# 235/235 [==============================] - 7s 28ms/step - loss: 0.0137 - root_mean_squared_error: 0.1722 - val_loss: 0.0979 - val_root_mean_squared_error: 0.5041 - lr: 1.0000e-05
# Epoch 103/50000
# 235/235 [==============================] - 7s 28ms/step - loss: 0.0144 - root_mean_squared_error: 0.1795 - val_loss: 0.0984 - val_root_mean_squared_error: 0.5052 - lr: 1.0000e-06
# Epoch 104/50000
# 235/235 [==============================] - 7s 28ms/step - loss: 0.0148 - root_mean_squared_error: 0.1827 - val_loss: 0.0962 - val_root_mean_squared_error: 0.4987 - lr: 1.0000e-06
# Epoch 105/50000
# 235/235 [==============================] - 6s 27ms/step - loss: 0.0141 - root_mean_squared_error: 0.1795 - val_loss: 0.0987 - val_root_mean_squared_error: 0.5047 - lr: 1.0000e-06
# Epoch 106/50000
# 235/235 [==============================] - 7s 28ms/step - loss: 0.0147 - root_mean_squared_error: 0.1804 - val_loss: 0.0987 - val_root_mean_squared_error: 0.5038 - lr: 1.0000e-06
# Epoch 107/50000
# 235/235 [==============================] - 6s 28ms/step - loss: 0.0147 - root_mean_squared_error: 0.1820 - val_loss: 0.0981 - val_root_mean_squared_error: 0.5009 - lr: 1.0000e-06
# Epoch 108/50000
# 235/235 [==============================] - 6s 28ms/step - loss: 0.0147 - root_mean_squared_error: 0.1850 - val_loss: 0.0982 - val_root_mean_squared_error: 0.5006 - lr: 1.0000e-06
# Epoch 109/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0145 - root_mean_squared_error: 0.1801 - val_loss: 0.0969 - val_root_mean_squared_error: 0.4984 - lr: 1.0000e-06
# Epoch 110/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0137 - root_mean_squared_error: 0.1729 - val_loss: 0.0970 - val_root_mean_squared_error: 0.4973 - lr: 1.0000e-06
# Epoch 111/50000
# 235/235 [==============================] - 7s 28ms/step - loss: 0.0146 - root_mean_squared_error: 0.1865 - val_loss: 0.0988 - val_root_mean_squared_error: 0.5035 - lr: 1.0000e-06
# Epoch 112/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0141 - root_mean_squared_error: 0.1770 - val_loss: 0.0982 - val_root_mean_squared_error: 0.5018 - lr: 1.0000e-06
# Epoch 113/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0147 - root_mean_squared_error: 0.1815 - val_loss: 0.0972 - val_root_mean_squared_error: 0.4991 - lr: 1.0000e-06
# Epoch 114/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0145 - root_mean_squared_error: 0.1825 - val_loss: 0.0958 - val_root_mean_squared_error: 0.4930 - lr: 1.0000e-06
# Epoch 115/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0151 - root_mean_squared_error: 0.1828 - val_loss: 0.0973 - val_root_mean_squared_error: 0.5017 - lr: 1.0000e-06
# Epoch 116/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0154 - root_mean_squared_error: 0.1866 - val_loss: 0.0978 - val_root_mean_squared_error: 0.5028 - lr: 1.0000e-06
# Epoch 117/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0149 - root_mean_squared_error: 0.1834 - val_loss: 0.0971 - val_root_mean_squared_error: 0.4995 - lr: 1.0000e-06
# Epoch 118/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0145 - root_mean_squared_error: 0.1841 - val_loss: 0.0968 - val_root_mean_squared_error: 0.4977 - lr: 1.0000e-06
# Epoch 119/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0148 - root_mean_squared_error: 0.1826 - val_loss: 0.0982 - val_root_mean_squared_error: 0.5029 - lr: 1.0000e-06
# Epoch 120/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0140 - root_mean_squared_error: 0.1770 - val_loss: 0.0963 - val_root_mean_squared_error: 0.4977 - lr: 1.0000e-06
# Epoch 121/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0138 - root_mean_squared_error: 0.1755 - val_loss: 0.0964 - val_root_mean_squared_error: 0.4968 - lr: 1.0000e-06
# Epoch 122/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0153 - root_mean_squared_error: 0.1876 - val_loss: 0.0975 - val_root_mean_squared_error: 0.5011 - lr: 1.0000e-06
# Epoch 123/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0157 - root_mean_squared_error: 0.1910 - val_loss: 0.0968 - val_root_mean_squared_error: 0.4995 - lr: 1.0000e-07
# Epoch 124/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0156 - root_mean_squared_error: 0.1855 - val_loss: 0.0973 - val_root_mean_squared_error: 0.5008 - lr: 1.0000e-07
# Epoch 125/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0140 - root_mean_squared_error: 0.1735 - val_loss: 0.0999 - val_root_mean_squared_error: 0.5098 - lr: 1.0000e-07
# Epoch 126/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0140 - root_mean_squared_error: 0.1795 - val_loss: 0.0968 - val_root_mean_squared_error: 0.4978 - lr: 1.0000e-07
# Epoch 127/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0143 - root_mean_squared_error: 0.1820 - val_loss: 0.0970 - val_root_mean_squared_error: 0.4971 - lr: 1.0000e-07
# Epoch 128/50000
# 235/235 [==============================] - 7s 31ms/step - loss: 0.0137 - root_mean_squared_error: 0.1742 - val_loss: 0.0980 - val_root_mean_squared_error: 0.5045 - lr: 1.0000e-07
# Epoch 129/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0141 - root_mean_squared_error: 0.1768 - val_loss: 0.0979 - val_root_mean_squared_error: 0.5028 - lr: 1.0000e-07
# Epoch 130/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0138 - root_mean_squared_error: 0.1751 - val_loss: 0.0970 - val_root_mean_squared_error: 0.5010 - lr: 1.0000e-07
# Epoch 131/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0136 - root_mean_squared_error: 0.1727 - val_loss: 0.0963 - val_root_mean_squared_error: 0.4975 - lr: 1.0000e-07
# Epoch 132/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0141 - root_mean_squared_error: 0.1786 - val_loss: 0.0979 - val_root_mean_squared_error: 0.5011 - lr: 1.0000e-07
# Epoch 133/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0132 - root_mean_squared_error: 0.1718 - val_loss: 0.0987 - val_root_mean_squared_error: 0.5040 - lr: 1.0000e-07
# Epoch 134/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0149 - root_mean_squared_error: 0.1827 - val_loss: 0.0977 - val_root_mean_squared_error: 0.5019 - lr: 1.0000e-07
# Epoch 135/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0149 - root_mean_squared_error: 0.1853 - val_loss: 0.0995 - val_root_mean_squared_error: 0.5071 - lr: 1.0000e-07
# Epoch 136/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0147 - root_mean_squared_error: 0.1854 - val_loss: 0.0969 - val_root_mean_squared_error: 0.4989 - lr: 1.0000e-07
# Epoch 137/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0150 - root_mean_squared_error: 0.1885 - val_loss: 0.0978 - val_root_mean_squared_error: 0.5010 - lr: 1.0000e-07
# Epoch 138/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0144 - root_mean_squared_error: 0.1803 - val_loss: 0.0976 - val_root_mean_squared_error: 0.4995 - lr: 1.0000e-07
# Epoch 139/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0141 - root_mean_squared_error: 0.1796 - val_loss: 0.0980 - val_root_mean_squared_error: 0.5039 - lr: 1.0000e-07
# Epoch 140/50000
# 235/235 [==============================] - 7s 31ms/step - loss: 0.0141 - root_mean_squared_error: 0.1791 - val_loss: 0.0972 - val_root_mean_squared_error: 0.4997 - lr: 1.0000e-07
# Epoch 141/50000
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0143 - root_mean_squared_error: 0.1792 - val_loss: 0.0989 - val_root_mean_squared_error: 0.5047 - lr: 1.0000e-07
# Epoch 142/50000
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0158 - root_mean_squared_error: 0.1905 - val_loss: 0.0977 - val_root_mean_squared_error: 0.5030 - lr: 1.0000e-07
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 138
#     136 try:
#     137     X, y = df_to_X_y(predictdf, window_size, sensor)
# --> 138     predX = model1.predict(X[k:k+1].astype('float32'), verbose=0)
#     139     nbr = predX[0][0]
#     140 except Exception as e:
#
# File /usr/local/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /usr/local/lib/python3.11/site-packages/keras/src/engine/training.py:2651, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2649     self._steps_per_execution_tuner.start()
#    2650 batch_outputs = None
# -> 2651 for _, iterator in data_handler.enumerate_epochs():  # Single epoch.
#    2652     with data_handler.catch_stop_iteration():
#    2653         for step in data_handler.steps():
#
# File /usr/local/lib/python3.11/site-packages/keras/src/engine/data_adapter.py:1341, in DataHandler.enumerate_epochs(self)
#    1339 """Yields `(epoch, tf.data.Iterator)`."""
#    1340 with self._truncate_execution_to_epoch():
# -> 1341     data_iterator = iter(self._dataset)
#    1342     for epoch in range(self._initial_epoch, self._epochs):
#    1343         if self._insufficient_data:  # Set by `catch_stop_iteration`.
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/data/ops/dataset_ops.py:500, in DatasetV2.__iter__(self)
#     498 if context.executing_eagerly() or ops.inside_function():
#     499   with ops.colocate_with(self._variant_tensor):
# --> 500     return iterator_ops.OwnedIterator(self)
#     501 else:
#     502   raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#     503                      "iteration in eager mode or within tf.function.")
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/data/ops/iterator_ops.py:706, in OwnedIterator.__init__(self, dataset, components, element_spec)
#     702   if (components is not None or element_spec is not None):
#     703     raise ValueError(
#     704         "When `dataset` is provided, `element_spec` and `components` must "
#     705         "not be specified.")
# --> 706   self._create_iterator(dataset)
#     708 self._get_next_call_count = 0
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/data/ops/iterator_ops.py:745, in OwnedIterator._create_iterator(self, dataset)
#     742   assert len(fulltype.args[0].args[0].args) == len(
#     743       self._flat_output_types)
#     744   self._iterator_resource.op.experimental_set_type(fulltype)
# --> 745 gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/ops/gen_dataset_ops.py:3421, in make_iterator(dataset, iterator, name)
#    3419 if tld.is_eager:
#    3420   try:
# -> 3421     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3422       _ctx, "MakeIterator", name, dataset, iterator)
#    3423     return _result
#    3424   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
import pandas as pd
import folium

# Read the CSV file
df = pd.read_csv('RothBorders.csv')

# Function to parse WKT and extract coordinates
def parse_wkt(wkt_str):
    # Remove "POLYGON ((" and "))" from the WKT string
    wkt_str = wkt_str.replace("POLYGON ((", "").replace("))", "")
    # Split the coordinates by comma
    coords = wkt_str.split(", ")
    # Split each coordinate pair by space and convert to float
    coords = [(float(coord.split()[1]), float(coord.split()[0])) for coord in coords]
    return coords

# Extract all coordinates from the WKT column
all_coords = df['WKT'].apply(parse_wkt)

# Calculate the center of the map
all_latitudes = [lat for coords in all_coords for lat, lon in coords]
all_longitudes = [lon for coords in all_coords for lat, lon in coords]
center = [sum(all_latitudes) / len(all_latitudes), sum(all_longitudes) / len(all_longitudes)]

# Create a map centered around the calculated center
m = folium.Map(location=center, zoom_start=12)

# Iterate through the rows of the DataFrame and add shapes to the map
for _, row in df.iterrows():
    # Parse the WKT geometry
    coords = parse_wkt(row['WKT'])
    
    # Add the polygon to the map with a click event to update the sidebar
    polygon = folium.Polygon(
        locations=coords,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.5
    )
    polygon.add_child(folium.Popup(row['name']))
    polygon.add_to(m)

# Save the map to an HTML file
m.save('roth_map.html')

# Add custom HTML and JavaScript for the info box
with open('roth_map.html', 'r') as file:
    map_html = file.read()

custom_html = f"""
<!DOCTYPE html>
<html>
<head>
    <title>Roth Borders Map</title>
    <style>
        #map {{
            width: 100%;
            height: 100vh;
        }}
        #info-box {{
            position: absolute;
            top: 10px;
            right: 10px;
            width: 200px;
            padding: 10px;
            background-color: white;
            border: 1px solid #ddd;
            box-shadow: 0 0 10px rgba(0, 0, 0, 0.1);
            z-index: 1000;
        }}
    </style>
</head>
<body>
    <div id="map"></div>
    <div id="info-box">
        <h4>Catchment Information</h4>
        <div id="catchment-name">Click on a catchment to see its name here.</div>
    </div>
    <script>
        {map_html}
        function updateInfoBox(name) {{
            document.getElementById('catchment-name').innerText = name;
        }}
        var polygons = document.getElementsByClassName('leaflet-interactive');
        for (var i = 0; i < polygons.length; i++) {{
            polygons[i].addEventListener('click', function() {{
                var popup = this._popup;
                if (popup) {{
                    var name = popup.getContent();
                    updateInfoBox(name);
                }}
            }});
        }}
    </script>
</body>
</html>
"""

with open('roth_map_with_info_box.html', 'w') as file:
    file.write(custom_html)

# %%
import folium

# Create a map centered around the Roth catchment
m = folium.Map(location=[50.770828, -3.907471], zoom_start=14)

folium.Marker(
    location=[50.770828, -3.907471],
    popup='Roth Catchment',
    icon=folium.Icon(color='green')
).add_to(m)







m

# %%
import pandas as pd
import folium

# Read the CSV file
df = pd.read_csv('RothBorders.csv')

# Function to parse WKT and extract coordinates
def parse_wkt(wkt_str):
    # Remove "POLYGON ((" and "))" from the WKT string
    wkt_str = wkt_str.replace("POLYGON ((", "").replace("))", "")
    # Split the coordinates by comma
    coords = wkt_str.split(", ")
    # Split each coordinate pair by space and convert to float
    coords = [(float(coord.split()[1]), float(coord.split()[0])) for coord in coords]
    return coords

# Extract all coordinates from the WKT column
all_coords = df['WKT'].apply(parse_wkt)

# Calculate the center of the map
all_latitudes = [lat for coords in all_coords for lat, lon in coords]
all_longitudes = [lon for coords in all_coords for lat, lon in coords]
center = [sum(all_latitudes) / len(all_latitudes), sum(all_longitudes) / len(all_longitudes)]

# Create a map centered around the calculated center
m = folium.Map(location=center, zoom_start=14)
# Iterate through the rows of the DataFrame and add shapes to the map
for _, row in df.iterrows():
    # Parse the WKT geometry
    coords = parse_wkt(row['WKT'])
    
    # Add the polygon to the map with a click event to update the sidebar
    polygon = folium.Polygon(
        locations=coords,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.5
    )
    polygon.add_child(folium.Popup(row['name']))
    polygon.add_to(m)

# Save the map to an HTML file
m.save('roth_map.html')
m

# %%
import pandas as pd
import folium
import matplotlib.pyplot as plt
import base64
from io import BytesIO
import time

# Read the CSV files
df = pd.read_csv('RothBorders.csv')
uncertain_df = pd.read_csv('uncertainReplaced.csv')

# Function to parse WKT and extract coordinates
def parse_wkt(wkt_str):
    # Remove "POLYGON ((" and "))" from the WKT string
    wkt_str = wkt_str.replace("POLYGON ((", "").replace("))", "")
    # Split the coordinates by comma
    coords = wkt_str.split(", ")
    # Split each coordinate pair by space and convert to float
    coords = [(float(coord.split()[1]), float(coord.split()[0])) for coord in coords]
    return coords

# Function to create a graph and return it as a base64 string
def create_graph(data, title):
    fig, ax = plt.subplots()
    data.plot(kind='bar', ax=ax)
    ax.set_title(title)
    buf = BytesIO()
    plt.savefig(buf, format='png')
    buf.seek(0)
    img_base64 = base64.b64encode(buf.read()).decode('utf-8')
    plt.close(fig)
    return img_base64

# Extract all coordinates from the WKT column
start_time = time.time()
all_coords = df['WKT'].apply(parse_wkt)
print(f"Parsed WKT coordinates in {time.time() - start_time:.2f} seconds")

# Calculate the center of the map
all_latitudes = [lat for coords in all_coords for lat, lon in coords]
all_longitudes = [lon for coords in all_coords for lat, lon in coords]
center = [sum(all_latitudes) / len(all_latitudes), sum(all_longitudes) / len(all_longitudes)]

# Create a map centered around the calculated center
m = folium.Map(location=center, zoom_start=14)

# Iterate through the rows of the DataFrame and add shapes to the map
for _, row in df.iterrows():
    # Parse the WKT geometry
    coords = parse_wkt(row['WKT'])
    
    # Create the HTML for the popup
    popup_html = f"<h4>{row['name']}</h4>"
    
    # Check for any column names in uncertain_df that contain the name of the polygon
    for col in uncertain_df.columns:
        if (row['name']+']') in col:
            # Check if the column contains numeric data
            try:
                numeric_data = pd.to_numeric(uncertain_df[col])
                graph_base64 = create_graph(numeric_data, col)
                popup_html += f'<img src="data:image/png;base64,{graph_base64}"><br>'
            except ValueError:
                # Skip columns that cannot be converted to numeric data
                continue
    
    # Add the polygon to the map with a click event to update the sidebar
    polygon = folium.Polygon(
        locations=coords,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.5
    )
    polygon.add_child(folium.Popup(popup_html, max_width=300))
    polygon.add_to(m)

# Save the map to an HTML file
m.save('roth_map.html')

# Add custom HTML and JavaScript for the info box
with open('roth_map.html', 'r') as file:
    map_html = file.read()

custom_html = f"""
<!DOCTYPE html>
<html>
<head>
    <title>Roth Borders Map</title>
    <style>
        #map {{
            width: 100%;
            height: 100vh;
        }}
        #info-box {{
            position: absolute;
            top: 10px;
            right: 10px;
            width: 200px;
            padding: 10px;
            background-color: white;
            border: 1px solid #ddd;
            box-shadow: 0 0 10px rgba(0, 0, 0, 0.1);
            z-index: 1000;
        }}
    </style>
</head>
<body>
    <div id="map"></div>
    <div id="info-box">
        <h4>Catchment Information</h4>
        <div id="catchment-name">Click on a catchment to see its name here.</div>
    </div>
    <script>
        {map_html}
        function updateInfoBox(name) {{
            document.getElementById('catchment-name').innerText = name;
        }}
        var polygons = document.getElementsByClassName('leaflet-interactive');
        for (var i = 0; i < polygons.length; i++) {{
            polygons[i].addEventListener('click', function() {{
                var popup = this._popup;
                if (popup) {{
                    var name = popup.getContent();
                    updateInfoBox(name);
                }}
            }});
        }}
    </script>
</body>
</html>
"""

with open('roth_map_with_info_box.html', 'w') as file:
    file.write(custom_html)

print(f"Script completed in {time.time() - start_time:.2f} seconds")

# %%
import pandas as pd
import folium
import matplotlib.pyplot as plt
import base64
from io import BytesIO
import time

# Read the CSV files
df = pd.read_csv('RothBorders.csv')
uncertain_df = pd.read_csv('uncertainReplaced.csv')

# Function to parse WKT and extract coordinates
def parse_wkt(wkt_str):
    # Remove "POLYGON ((" and "))" from the WKT string
    wkt_str = wkt_str.replace("POLYGON ((", "").replace("))", "")
    # Split the coordinates by comma
    coords = wkt_str.split(", ")
    # Split each coordinate pair by space and convert to float
    coords = [(float(coord.split()[1]), float(coord.split()[0])) for coord in coords]
    return coords

# Function to create a graph and return it as a base64 string
def create_graph(data, title):
    fig, ax = plt.subplots()
    data.plot(kind='bar', ax=ax)
    ax.set_title(title)
    buf = BytesIO()
    plt.savefig(buf, format='png')
    buf.seek(0)
    img_base64 = base64.b64encode(buf.read()).decode('utf-8')
    plt.close(fig)
    return img_base64

# Extract all coordinates from the WKT column
start_time = time.time()
all_coords = df['WKT'].apply(parse_wkt)
print(f"Parsed WKT coordinates in {time.time() - start_time:.2f} seconds")

# Calculate the center of the map
all_latitudes = [lat for coords in all_coords for lat, lon in coords]
all_longitudes = [lon for coords in all_coords for lat, lon in coords]
center = [sum(all_latitudes) / len(all_latitudes), sum(all_longitudes) / len(all_longitudes)]

# Create a map centered around the calculated center
m = folium.Map(location=center, zoom_start=14)

# Iterate through the rows of the DataFrame and add shapes to the map
for _, row in df.iterrows():
    # Parse the WKT geometry
    coords = parse_wkt(row['WKT'])
    
    # Create the HTML for the popup
    popup_html = f"<h4>{row['name']}</h4>"
    
    # Check for any column names in uncertain_df that contain the name of the polygon
    for col in uncertain_df.columns:
        if (row['name']+']') in col:
            # Check if the column contains numeric data
            try:
                numeric_data = pd.to_numeric(uncertain_df[col])
                graph_base64 = create_graph(numeric_data, col)
                popup_html += f'<img src="data:image/png;base64,{graph_base64}"><br>'
            except ValueError:
                # Skip columns that cannot be converted to numeric data
                continue
    
    # Add the polygon to the map with a click event to update the sidebar
    polygon = folium.Polygon(
        locations=coords,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.5
    )
    polygon.add_child(folium.Popup(popup_html, max_width=300))
    polygon.add_to(m)

# Save the map to an HTML file
m.save('roth_map.html')

# Add custom HTML and JavaScript for the info box
with open('roth_map.html', 'r') as file:
    map_html = file.read()

custom_html = f"""
<!DOCTYPE html>
<html>
<head>
    <title>Roth Borders Map</title>
    <style>
        #map {{
            width: 100%;
            height: 100vh;
        }}
        #info-box {{
            position: absolute;
            top: 10px;
            right: 10px;
            width: 200px;
            padding: 10px;
            background-color: white;
            border: 1px solid #ddd;
            box-shadow: 0 0 10px rgba(0, 0, 0, 0.1);
            z-index: 1000;
        }}
    </style>
</head>
<body>
    <div id="map"></div>
    <div id="info-box">
        <h4>Catchment Information</h4>
        <div id="catchment-name">Click on a catchment to see its name here.</div>
        <div id="catchment-graph"></div>
    </div>
    <script>
        {map_html}
        function updateInfoBox(name, graph) {{
            document.getElementById('catchment-name').innerText = name;
            document.getElementById('catchment-graph').innerHTML = graph;
        }}
        var polygons = document.getElementsByClassName('leaflet-interactive');
        for (var i = 0; i < polygons.length; i++) {{
            polygons[i].addEventListener('click', function() {{
                var popup = this._popup;
                if (popup) {{
                    var content = popup.getContent();
                    var parser = new DOMParser();
                    var doc = parser.parseFromString(content, 'text/html');
                    var name = doc.querySelector('h4').innerText;
                    var graph = doc.querySelector('img').outerHTML;
                    updateInfoBox(name, graph);
                }}
            }});
        }}
    </script>
</body>
</html>
"""

with open('roth_map_with_info_box.html', 'w') as file:
    file.write(custom_html)

print(f"Script completed in {time.time() - start_time:.2f} seconds")

# %%
import pandas as pd
import folium
import matplotlib.pyplot as plt
import base64
from io import BytesIO
import time

# Read the CSV files
df = pd.read_csv('RothBorders.csv')
uncertain_df = pd.read_csv('uncertainReplaced.csv')

# Function to parse WKT and extract coordinates
def parse_wkt(wkt_str):
    # Remove "POLYGON ((" and "))" from the WKT string
    wkt_str = wkt_str.replace("POLYGON ((", "").replace("))", "")
    # Split the coordinates by comma
    coords = wkt_str.split(", ")
    # Split each coordinate pair by space and convert to float
    coords = [(float(coord.split()[1]), float(coord.split()[0])) for coord in coords]
    return coords

# Function to create a graph and return it as a base64 string
def create_graph(data, title):
    fig, ax = plt.subplots()
    data.plot(kind='bar', ax=ax)
    ax.set_title(title)
    buf = BytesIO()
    plt.savefig(buf, format='png')
    buf.seek(0)
    img_base64 = base64.b64encode(buf.read()).decode('utf-8')
    plt.close(fig)
    return img_base64

# Extract all coordinates from the WKT column
start_time = time.time()
all_coords = df['WKT'].apply(parse_wkt)
print(f"Parsed WKT coordinates in {time.time() - start_time:.2f} seconds")

# Calculate the center of the map
all_latitudes = [lat for coords in all_coords for lat, lon in coords]
all_longitudes = [lon for coords in all_coords for lat, lon in coords]
center = [sum(all_latitudes) / len(all_latitudes), sum(all_longitudes) / len(all_longitudes)]

# Create a map centered around the calculated center
m = folium.Map(location=center, zoom_start=14)

# Iterate through the rows of the DataFrame and add shapes to the map
for _, row in df.iterrows():
    # Parse the WKT geometry
    coords = parse_wkt(row['WKT'])
    
    # Create the HTML for the popup
    popup_html = f"<h4>{row['name']}</h4>"
    
    # Check for any column names in uncertain_df that contain the name of the polygon
    for col in uncertain_df.columns:
        if (row['name']+']') in col:
            # Check if the column contains numeric data
            try:
                numeric_data = pd.to_numeric(uncertain_df[col])
                graph_base64 = create_graph(numeric_data, col)
                popup_html += f'<img src="data:image/png;base64,{graph_base64}"><br>'
            except ValueError:
                # Skip columns that cannot be converted to numeric data
                continue
    
    # Add the polygon to the map with a click event to update the sidebar
    polygon = folium.Polygon(
        locations=coords,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.5
    )
    polygon.add_child(folium.Popup(popup_html, max_width=300))
    polygon.add_to(m)

# Save the map to an HTML file
m.save('roth_map.html')

# Add custom HTML and JavaScript for the info box
with open('roth_map.html', 'r') as file:
    map_html = file.read()

custom_html = f"""
<!DOCTYPE html>
<html>
<head>
    <title>Roth Borders Map</title>
    <style>
        #map {{
            width: 100%;
            height: 100vh;
        }}
        #info-box {{
            position: absolute;
            top: 10px;
            right: 10px;
            width: 200px;
            padding: 10px;
            background-color: white;
            border: 1px solid #ddd;
            box-shadow: 0 0 10px rgba(0, 0, 0, 0.1);
            z-index: 1000;
        }}
    </style>
</head>
<body>
    <div id="map"></div>
    <div id="info-box">
        <h4>Catchment Information</h4>
        <div id="catchment-name">Click on a catchment to see its name here.</div>
        <div id="catchment-graph"></div>
    </div>
    {map_html}
    <script>
        function updateInfoBox(name, graph) {{
            document.getElementById('catchment-name').innerText = name;
            document.getElementById('catchment-graph').innerHTML = graph;
        }}
        var polygons = document.getElementsByClassName('leaflet-interactive');
        for (var i = 0; i < polygons.length; i++) {{
            polygons[i].addEventListener('click', function() {{
                var popup = this._popup;
                if (popup) {{
                    var content = popup.getContent();
                    var parser = new DOMParser();
                    var doc = parser.parseFromString(content, 'text/html');
                    var name = doc.querySelector('h4').innerText;
                    var graph = doc.querySelector('img') ? doc.querySelector('img').outerHTML : '';
                    updateInfoBox(name, graph);
                }}
            }});
        }}
    </script>
</body>
</html>
"""

with open('roth_map_with_info_box.html', 'w') as file:
    file.write(custom_html)

print(f"Script completed in {time.time() - start_time:.2f} seconds")

# %%
import pandas as pd
import folium
import matplotlib.pyplot as plt
import base64
from io import BytesIO
import time

# Read the CSV files
df = pd.read_csv('RothBorders.csv')
uncertain_df = pd.read_csv('uncertainReplaced.csv')

# Function to parse WKT and extract coordinates
def parse_wkt(wkt_str):
    # Remove "POLYGON ((", and "))" from the WKT string
    wkt_str = wkt_str.replace("POLYGON ((", "").replace("))", "")
    # Split the coordinates by comma
    coords = wkt_str.split(", ")
    # Split each coordinate pair by space and convert to float
    coords = [(float(coord.split()[1]), float(coord.split()[0])) for coord in coords]
    return coords

# Function to create a graph and return it as a base64 string
def create_graph(data, title):
    fig, ax = plt.subplots()
    data.plot(kind='bar', ax=ax)
    ax.set_title(title)
    buf = BytesIO()
    plt.savefig(buf, format='png')
    buf.seek(0)
    img_base64 = base64.b64encode(buf.read()).decode('utf-8')
    plt.close(fig)
    return img_base64

# Extract all coordinates from the WKT column
start_time = time.time()
all_coords = df['WKT'].apply(parse_wkt)
print(f"Parsed WKT coordinates in {time.time() - start_time:.2f} seconds")

# Calculate the center of the map
all_latitudes = [lat for coords in all_coords for lat, lon in coords]
all_longitudes = [lon for coords in all_coords for lat, lon in coords]
center = [sum(all_latitudes) / len(all_latitudes), sum(all_longitudes) / len(all_longitudes)]

# Create a map centered around the calculated center
m = folium.Map(location=center, zoom_start=14)

# Iterate through the rows of the DataFrame and add shapes to the map
for _, row in df.iterrows():
    # Parse the WKT geometry
    coords = parse_wkt(row['WKT'])
    
    # Create the HTML for the popup
    popup_html = f"<h4>{row['name']}</h4>"
    
    # Check for any column names in uncertain_df that contain the name of the polygon
    for col in uncertain_df.columns:
        if (row['name']+']') in col:
            # Check if the column contains numeric data
            try:
                numeric_data = pd.to_numeric(uncertain_df[col])
                graph_base64 = create_graph(numeric_data, col)
                popup_html += f'<img src="data:image/png;base64,{graph_base64}"><br>'
            except ValueError:
                # Skip columns that cannot be converted to numeric data
                continue
    
    # Add the polygon to the map with a click event to update the sidebar
    polygon = folium.Polygon(
        locations=coords,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.5
    )
    polygon.add_child(folium.Popup(popup_html, max_width=300))
    polygon.add_to(m)

# Save the map to an HTML file
m.save('roth_map.html')

# Add custom HTML and JavaScript for the info box
with open('roth_map.html', 'r') as file:
    map_html = file.read()

custom_html = f"""
<!DOCTYPE html>
<html>
<head>
    <title>Roth Borders Map</title>
    <style>
        #map {{
            width: 100%;
            height: 100vh;
        }}
        #info-box {{
            position: absolute;
            top: 10px;
            right: 10px;
            width: 200px;
            padding: 10px;
            background-color: white;
            border: 1px solid #ddd;
            box-shadow: 0 0 10px rgba(0, 0, 0, 0.1);
            z-index: 1000;
            overflow-y: auto;
            max-height: 90vh;
        }}
        .leaflet-popup-content {{
            max-height: 400px;
            overflow-y: auto;
        }}
    </style>
</head>
<body>
    <div id="map"></div>
    <div id="info-box">
        <h4>Catchment Information</h4>
        <div id="catchment-name">Click on a catchment to see its name here.</div>
        <div id="catchment-graph"></div>
    </div>
    {map_html}
    <script>
        function updateInfoBox(name, graph) {{
            document.getElementById('catchment-name').innerText = name;
            document.getElementById('catchment-graph').innerHTML = graph;
        }}
        var polygons = document.getElementsByClassName('leaflet-interactive');
        for (var i = 0; i < polygons.length; i++) {{
            polygons[i].addEventListener('click', function() {{
                var popup = this._popup;
                if (popup) {{
                    var content = popup.getContent();
                    var parser = new DOMParser();
                    var doc = parser.parseFromString(content, 'text/html');
                    var name = doc.querySelector('h4').innerText;
                    var graph = doc.querySelector('img') ? doc.querySelector('img').outerHTML : '';
                    updateInfoBox(name, graph);
                }}
            }});
        }}
    </script>
</body>
</html>
"""

with open('roth_map_with_info_box.html', 'w') as file:
    file.write(custom_html)

print(f"Script completed in {time.time() - start_time:.2f} seconds")

# %%
import pandas as pd
import folium
import matplotlib.pyplot as plt
import base64
from io import BytesIO
import time

# Read the CSV files
df = pd.read_csv('RothBorders.csv')
uncertain_df = pd.read_csv('uncertainReplaced.csv')

# Function to parse WKT and extract coordinates
def parse_wkt(wkt_str):
    # Remove "POLYGON ((", and "))" from the WKT string
    wkt_str = wkt_str.replace("POLYGON ((", "").replace("))", "")
    # Split the coordinates by comma
    coords = wkt_str.split(", ")
    # Split each coordinate pair by space and convert to float
    coords = [(float(coord.split()[1]), float(coord.split()[0])) for coord in coords]
    return coords

# Function to create a graph and return it as a base64 string
def create_graph(data, title):
    fig, ax = plt.subplots()
    data.plot(kind='bar', ax=ax)
    ax.set_title(title)
    ax.set_xticklabels([])  # Remove x-axis labels
    buf = BytesIO()
    plt.savefig(buf, format='png')
    buf.seek(0)
    img_base64 = base64.b64encode(buf.read()).decode('utf-8')
    plt.close(fig)
    return img_base64

# Extract all coordinates from the WKT column
start_time = time.time()
all_coords = df['WKT'].apply(parse_wkt)
print(f"Parsed WKT coordinates in {time.time() - start_time:.2f} seconds")

# Calculate the center of the map
all_latitudes = [lat for coords in all_coords for lat, lon in coords]
all_longitudes = [lon for coords in all_coords for lat, lon in coords]
center = [sum(all_latitudes) / len(all_latitudes), sum(all_longitudes) / len(all_longitudes)]

# Create a map centered around the calculated center
m = folium.Map(location=center, zoom_start=14)

# Iterate through the rows of the DataFrame and add shapes to the map
for _, row in df.iterrows():
    # Parse the WKT geometry
    coords = parse_wkt(row['WKT'])
    
    # Create the HTML for the popup
    popup_html = f"<h4>{row['name']}</h4>"
    
    # Check for any column names in uncertain_df that contain the name of the polygon
    for col in uncertain_df.columns:
        if (row['name']+']') in col:
            # Check if the column contains numeric data
            try:
                numeric_data = pd.to_numeric(uncertain_df[col])
                graph_base64 = create_graph(numeric_data, col)
                popup_html += f'<img src="data:image/png;base64,{graph_base64}"><br>'
            except ValueError:
                # Skip columns that cannot be converted to numeric data
                continue
    
    # Add the polygon to the map with a click event to update the sidebar
    polygon = folium.Polygon(
        locations=coords,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.5
    )
    polygon.add_child(folium.Popup(popup_html, max_width=500))  # Increase max_width to 500
    polygon.add_to(m)

# Save the map to an HTML file
m.save('roth_map.html')

# Add custom HTML and JavaScript for the info box
with open('roth_map.html', 'r') as file:
    map_html = file.read()

custom_html = f"""
<!DOCTYPE html>
<html>
<head>
    <title>Roth Borders Map</title>
    <style>
        #map {{
            width: 100%;
            height: 100vh;
        }}
        #info-box {{
            position: absolute;
            top: 10px;
            right: 10px;
            width: 200px;
            padding: 10px;
            background-color: white;
            border: 1px solid #ddd;
            box-shadow: 0 0 10px rgba(0, 0, 0, 0.1);
            z-index: 1000;
            overflow-y: auto;
            max-height: 90vh;
        }}
        .leaflet-popup-content {{
            max-height: 600px;
            overflow-y: auto;
        }}
    </style>
</head>
<body>
    <div id="map"></div>
    <div id="info-box">
        <h4>Catchment Information</h4>
        <div id="catchment-name">Click on a catchment to see its name here.</div>
        <div id="catchment-graph"></div>
    </div>
    {map_html}
    <script>
        function updateInfoBox(name, graph) {{
            document.getElementById('catchment-name').innerText = name;
            document.getElementById('catchment-graph').innerHTML = graph;
        }}
        var polygons = document.getElementsByClassName('leaflet-interactive');
        for (var i = 0; i < polygons.length; i++) {{
            polygons[i].addEventListener('click', function() {{
                var popup = this._popup;
                if (popup) {{
                    var content = popup.getContent();
                    var parser = new DOMParser();
                    var doc = parser.parseFromString(content, 'text/html');
                    var name = doc.querySelector('h4').innerText;
                    var graph = doc.querySelector('img') ? doc.querySelector('img').outerHTML : '';
                    updateInfoBox(name, graph);
                }}
            }});
        }}
    </script>
</body>
</html>
"""

with open('roth_map_with_info_box.html', 'w') as file:
    file.write(custom_html)

print(f"Script completed in {time.time() - start_time:.2f} seconds")

# %%
import pandas as pd
import folium
import plotly.express as px
import base64
from io import BytesIO
import time

# Read the CSV files
df = pd.read_csv('RothBorders.csv')
uncertain_df = pd.read_csv('uncertainReplaced.csv')

# Function to parse WKT and extract coordinates
def parse_wkt(wkt_str):
    # Remove "POLYGON ((", and "))" from the WKT string
    wkt_str = wkt_str.replace("POLYGON ((", "").replace("))", "")
    # Split the coordinates by comma
    coords = wkt_str.split(", ")
    # Split each coordinate pair by space and convert to float
    coords = [(float(coord.split()[1]), float(coord.split()[0])) for coord in coords]
    return coords

# Function to create an interactive graph and return it as an HTML string
def create_graph(data, title):
    fig = px.bar(data, title=title)
    fig.update_layout(xaxis_title=None, yaxis_title=None)
    graph_html = fig.to_html(full_html=False)
    return graph_html

# Extract all coordinates from the WKT column
start_time = time.time()
all_coords = df['WKT'].apply(parse_wkt)
print(f"Parsed WKT coordinates in {time.time() - start_time:.2f} seconds")

# Calculate the center of the map
all_latitudes = [lat for coords in all_coords for lat, lon in coords]
all_longitudes = [lon for coords in all_coords for lat, lon in coords]
center = [sum(all_latitudes) / len(all_latitudes), sum(all_longitudes) / len(all_longitudes)]

# Create a map centered around the calculated center
m = folium.Map(location=center, zoom_start=14)

# Iterate through the rows of the DataFrame and add shapes to the map
for _, row in df.iterrows():
    # Parse the WKT geometry
    coords = parse_wkt(row['WKT'])
    
    # Create the HTML for the popup
    popup_html = f"<h4>{row['name']}</h4>"
    
    # Check for any column names in uncertain_df that contain the name of the polygon
    for col in uncertain_df.columns:
        if (row['name']+']') in col:
            # Check if the column contains numeric data
            try:
                numeric_data = pd.to_numeric(uncertain_df[col])
                graph_html = create_graph(numeric_data, col)
                popup_html += f'{graph_html}<br>'
            except ValueError:
                # Skip columns that cannot be converted to numeric data
                continue
    
    # Add the polygon to the map with a click event to update the sidebar
    polygon = folium.Polygon(
        locations=coords,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.5
    )
    polygon.add_child(folium.Popup(popup_html, max_width=500))  # Increase max_width to 500
    polygon.add_to(m)

# Save the map to an HTML file
m.save('roth_map.html')

# Add custom HTML and JavaScript for the info box
with open('roth_map.html', 'r') as file:
    map_html = file.read()

custom_html = f"""
<!DOCTYPE html>
<html>
<head>
    <title>Roth Borders Map</title>
    <style>
        #map {{
            width: 100%;
            height: 100vh;
        }}
        #info-box {{
            position: absolute;
            top: 10px;
            right: 10px;
            width: 200px;
            padding: 10px;
            background-color: white;
            border: 1px solid #ddd;
            box-shadow: 0 0 10px rgba(0, 0, 0, 0.1);
            z-index: 1000;
            overflow-y: auto;
            max-height: 90vh;
        }}
        .leaflet-popup-content {{
            max-height: 600px;
            overflow-y: auto;
        }}
    </style>
</head>
<body>
    <div id="map"></div>
    <div id="info-box">
        <h4>Catchment Information</h4>
        <div id="catchment-name">Click on a catchment to see its name here.</div>
        <div id="catchment-graph"></div>
    </div>
    {map_html}
    <script>
        function updateInfoBox(name, graph) {{
            document.getElementById('catchment-name').innerText = name;
            document.getElementById('catchment-graph').innerHTML = graph;
        }}
        var polygons = document.getElementsByClassName('leaflet-interactive');
        for (var i = 0; i < polygons.length; i++) {{
            polygons[i].addEventListener('click', function() {{
                var popup = this._popup;
                if (popup) {{
                    var content = popup.getContent();
                    var parser = new DOMParser();
                    var doc = parser.parseFromString(content, 'text/html');
                    var name = doc.querySelector('h4').innerText;
                    var graph = doc.querySelector('div.plotly-graph-div') ? doc.querySelector('div.plotly-graph-div').outerHTML : '';
                    updateInfoBox(name, graph);
                }}
            }});
        }}
    </script>
</body>
</html>
"""

with open('roth_map_with_info_box.html', 'w') as file:
    file.write(custom_html)

print(f"Script completed in {time.time() - start_time:.2f} seconds")

# %%
import pandas as pd
import folium
import matplotlib.pyplot as plt
import base64
from io import BytesIO
import time

# Read the CSV files
df = pd.read_csv('RothBorders.csv')
uncertain_df = pd.read_csv('uncertainReplaced.csv')

# Function to parse WKT and extract coordinates
def parse_wkt(wkt_str):
    # Remove "POLYGON ((", and "))" from the WKT string
    wkt_str = wkt_str.replace("POLYGON ((", "").replace("))", "")
    # Split the coordinates by comma
    coords = wkt_str.split(", ")
    # Split each coordinate pair by space and convert to float
    coords = [(float(coord.split()[1]), float(coord.split()[0])) for coord in coords]
    return coords

# Function to create a graph and return it as a base64 string
def create_graph(data, title):
    fig, ax = plt.subplots()
    data.plot(kind='bar', ax=ax)
    ax.set_title(title)
    ax.set_xticklabels([])  # Remove x-axis labels
    buf = BytesIO()
    plt.savefig(buf, format='png')
    buf.seek(0)
    img_base64 = base64.b64encode(buf.read()).decode('utf-8')
    plt.close(fig)
    return img_base64

# Extract all coordinates from the WKT column
start_time = time.time()
all_coords = df['WKT'].apply(parse_wkt)
print(f"Parsed WKT coordinates in {time.time() - start_time:.2f} seconds")

# Calculate the center of the map
all_latitudes = [lat for coords in all_coords for lat, lon in coords]
all_longitudes = [lon for coords in all_coords for lat, lon in coords]
center = [sum(all_latitudes) / len(all_latitudes), sum(all_longitudes) / len(all_longitudes)]

# Create a map centered around the calculated center
m = folium.Map(location=center, zoom_start=14)

# Iterate through the rows of the DataFrame and add shapes to the map
for _, row in df.iterrows():
    # Parse the WKT geometry
    coords = parse_wkt(row['WKT'])
    
    # Create the HTML for the popup
    popup_html = f"<h4>{row['name']}</h4>"
    
    # Check for any column names in uncertain_df that contain the name of the polygon
    for col in uncertain_df.columns:
        if (row['name']+']') in col:
            # Check if the column contains numeric data
            try:
                numeric_data = pd.to_numeric(uncertain_df[col])
                graph_base64 = create_graph(numeric_data, col)
                popup_html += f'<img src="data:image/png;base64,{graph_base64}"><br>'
            except ValueError:
                # Skip columns that cannot be converted to numeric data
                continue
    
    # Add the polygon to the map with a click event to update the sidebar
    polygon = folium.Polygon(
        locations=coords,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.5
    )
    polygon.add_child(folium.Popup(popup_html, max_width=500))  # Increase max_width to 500
    polygon.add_to(m)

# Save the map to an HTML file
m.save('roth_map.html')

# Add custom HTML and JavaScript for the info box
with open('roth_map.html', 'r') as file:
    map_html = file.read()

custom_html = f"""
<!DOCTYPE html>
<html>
<head>
    <title>Roth Borders Map</title>
    <style>
        #map {{
            width: 100%;
            height: 100vh;
        }}
        #info-box {{
            position: absolute;
            top: 0px;
            right: 0px;
            height: 100%;
            width: 30%;
            padding: 10px;
            background-color: white;
            border: 1px solid #ddd;
            box-shadow: 0 0 10px rgba(0, 0, 0, 0.1);
            z-index: 1000;
            overflow-y: auto;
            max-height: 90vh;
        }}
        .leaflet-popup-content {{
            max-height: 600px;
            overflow-y: auto;
        }}
    </style>
</head>
<body>
    <div id="map"></div>
    <div id="info-box">
        <h4>Catchment Information</h4>
        <div id="catchment-name">Click on a catchment to see its name here.</div>
        <div id="catchment-graph"></div>
    </div>
    {map_html}
    <script>
        function updateInfoBox(name, graph) {{
            document.getElementById('catchment-name').innerText = name;
            document.getElementById('catchment-graph').innerHTML = graph;
        }}
        var polygons = document.getElementsByClassName('leaflet-interactive');
        for (var i = 0; i < polygons.length; i++) {{
            polygons[i].addEventListener('click', function() {{
                var popup = this._popup;
                if (popup) {{
                    var content = popup.getContent();
                    var parser = new DOMParser();
                    var doc = parser.parseFromString(content, 'text/html');
                    var name = doc.querySelector('h4').innerText;
                    var graph = doc.querySelector('img') ? doc.querySelector('img').outerHTML : '';
                    updateInfoBox(name, graph);
                }}
            }});
        }}
    </script>
</body>
</html>
"""

with open('roth_map_with_info_box_test.html', 'w') as file:
    file.write(custom_html)

print(f"Script completed in {time.time() - start_time:.2f} seconds")
